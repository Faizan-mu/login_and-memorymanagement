# %% [markdown]
#                   Files, exceptional handling, logging and
#                          memory management Questions
#
#  1:- HF What is the difference between interpreted and compiled languages?
#
#  Ans:-The key difference between compiled and interpreted languages lies in how the source code is executed. Compiled languages are translated into machine code before execution, while interpreted languages are executed line by line by an interpreter. This fundamental difference impacts performance, portability, and development workflow.
#
#  EXAMPLE:-
#  Python, JavaScript,Ruby
#
#  2:-What is exception handling in Python?
#
#  Ans:- Exception handling in Python is a mechanism used to manage and respond to errors or unexpected events that occur during the execution of a program. These errors, known as exceptions, can disrupt the normal flow of a program if not handled properly, potentially leading to program termination.
#
# The core components of exception handling in Python are:
#
# try block:
#
# This block contains the code that might potentially raise an exception.
#
# except block:
#
# This block is executed if an exception occurs within the corresponding try block. It specifies how to handle a particular type of exception or all exceptions. Multiple except blocks can be used to handle different types of exceptions.
#
# else block (optional):
#
# This block is executed if the code inside the try block runs without raising any exceptions.
#
# finally block (optional):
#
# This block is always executed, regardless of whether an exception occurred or not. It is typically used for cleanup operations, such as closing files or releasing resources.
#
# EXAMPLE:-
# try:
#
#     numerator = 10
#     denominator = 0
#     result = numerator / denominator
#     print(result)
# except ZeroDivisionError:
#
#     print("Error: Cannot divide by zero!")
# except TypeError:
#
#     print("Error: Incompatible data types for division.")
# else:
#
#     print("Division successful.")
# finally:
#
#     print("This code always executes.")
#
# In this example, if a ZeroDivisionError occurs in the try block (due to division by zero), the corresponding except ZeroDivisionError block is executed. If a TypeError occurs, the except TypeError block is executed. If no exceptions occur, the else block is executed. The finally block is always executed, providing a place for essential cleanup operations.
#
# 3:- What is the purpose of the finally block in exception handling?
#
# Ans:- The finally block in exception handling serves the purpose of ensuring that a specific block of code is executed, regardless of whether an exception occurs in the try block or is caught by a catch block.
#
# Its primary uses include:
#
# Resource Management:
#
# The finally block is crucial for releasing resources that have been acquired in the try block, such as closing file streams, database connections, or network sockets. This ensures that resources are properly deallocated, preventing resource leaks and maintaining system stability.
#
# Guaranteed Execution:
#
# Code within the finally block is guaranteed to execute, even if there's a return, break, or continue statement within the try or catch blocks, or if an unhandled exception occurs. This guarantees that critical cleanup or finalization tasks are always performed.
#
# Cleanup Operations:
#
# It provides a reliable place to put any necessary cleanup code that must run before the execution flow leaves the try-catch-finally construct. This includes resetting states, logging information, or any other actions required for proper program termination or continuation.
#
# 4:-  What is logging in Python?
#
# Ans:-Python logging refers to the process of tracking events that occur during the execution of a Python program. It involves recording information about the program's behavior, including errors, warnings, and other significant events, to aid in debugging, troubleshooting, and monitoring.
#
# The core of Python's logging functionality is provided by the built-in logging module in the standard library. This module offers a flexible and powerful system for generating and handling log messages.
#
# 5:-  What is the significance of the __del__ method in Python?
#
# Ans:- The __del__ method in Python, often referred to as a destructor, holds significance in object lifecycle management, particularly for resource cleanup.
#
# Key Significance:
#
# Resource Deallocation:
#
# The primary purpose of __del__ is to provide a mechanism for an object to perform cleanup actions when it is about to be destroyed. This is crucial for releasing external resources that the object might be holding, such as:
#
# Closing open file handles.
#
# Terminating network connections.
#
# Releasing database connections.
#
# Freeing up memory allocated by external C extensions.
#
# Automatic Invocation (Garbage Collection):
#
# Unlike regular methods, __del__ is not called explicitly by the programmer. Instead, it is automatically invoked by Python's garbage collector when an object's reference count drops to zero, meaning no more references to that object exist in the program.
#
# Last-Resort Cleanup:
#
# While not guaranteed to be executed at a precise time (due to the nature of garbage collection and potential circular references), __del__ serves as a last-resort mechanism to attempt resource cleanup if explicit close() or release() methods were not called by the user.
#
# 6:- What is the difference between import and from ... import in Python?
#
# Ans:- In Python, both import and from ... import statements are used to bring modules or specific components from modules into your current namespace, but they differ in how they make those components accessible:
#
# import module_name:
#
# This statement imports the entire module.
#
# To access any function, class, or variable within that module, you must prefix it with the module name and a dot (e.g., module_name.function_name(), module_name.ClassName).
#
# This method keeps your namespace cleaner by adding only one name (the module name) to it, reducing the chance of naming conflicts if you import multiple modules with similarly named components.
#
#     import math
#     result = math.sqrt(25)
#     print(result)
#
# from module_name import component_name:
#
# This statement imports only specific components (functions, classes, or variables) directly into your current namespace.
#
# You can then use the imported component directly without prefixing it with the module name.
#
# This can make your code more concise, especially if you frequently use a particular component from a module.
#
#     from math import sqrt
#     result = sqrt(25)
#     print(result)
#
# 7:- How can you handle multiple exceptions in Python?
#
# Ans:- In Python, multiple exceptions can be handled within try-except blocks using several approaches:
#
# 1. Handling Multiple Exceptions with a Single except Block:
#
# This approach is suitable when the same logic applies to handling different types of exceptions. You can specify multiple exception types as a tuple within a single except clause.
#
# try:
#
#     # Code that might raise exceptions
#     value = int(input("Enter a number: "))
#     result = 10 / value
# except (ValueError, ZeroDivisionError) as e:
#
#     print(f"An error occurred: {e}")
#     print("Please ensure you enter a valid non-zero number.")
#
#  2. Handling Multiple Exceptions with Separate except Blocks:
#
# When different exceptions require distinct handling logic, you can use separate except blocks for each exception type. The first except block that matches the raised exception will be executed.
#
# try:
#
#     # Code that might raise exceptions
#     file_content = open("non_existent_file.txt", "r").read()
# except FileNotFoundError:
#
#     print("Error: The specified file was not found.")
# except PermissionError:
#
#     print("Error: You do not have permission to access this file.")
# except Exception as e: # A generic catch-all for other unexpected exceptions
#
#     print(f"An unexpected error occurred: {e}")
#
# 3. Catching Exceptions Using Their Superclass:
#
# If multiple exceptions inherit from a common base class, you can catch the superclass to handle all its subclasses. This is useful for catching a broad category of related errors.
#
# try:
#
#     # Code that might raise exceptions like IndexError, KeyError, etc.
#     my_list = [1, 2, 3]
#     print(my_list[5]) # This will raise an IndexError
# except LookupError as e: # LookupError is the base class for IndexError and KeyError
#
#     print(f"A lookup error occurred: {e}")
#
# 4. Using except with a Generic Exception:
#
# You can use a generic except Exception as e: block to catch any unhandled exceptions. This should generally be placed as the last except block to avoid overshadowing more specific exception handlers.
#
# try:
#
#     # Code that might raise various exceptions
#     data = 1 / 0
# except ZeroDivisionError:
#
#     print("Cannot divide by zero.")
# except Exception as e:
#
#     print(f"An unexpected error occurred: {e}")
#
# Note: The order of except blocks matters. More specific exception types should be placed before more general ones to ensure they are handled appropriately.
#
# 8:- What is the purpose of the with statement when handling files in Python?
#
# Ansd:-The with statement in Python, when used with file handling, serves the primary purpose of ensuring that files are properly closed, even if errors occur during file operations. It achieves this by utilizing a concept known as "context managers."
#
# Here's a breakdown of its purpose:
#
# Automatic Resource Management:
#
# The with statement guarantees that a resource, such as a file, is automatically acquired (opened) at the beginning of the with block and released (closed) when the block is exited, regardless of whether the exit is normal or due to an exception. This eliminates the need for explicit file.close() calls, which can be easily forgotten, leading to resource leaks or file corruption.
#
# Simplified Error Handling:
#
# Traditionally, ensuring file closure in the face of errors required try...finally blocks. The with statement abstracts this complexity, making the code cleaner and more readable. If an exception occurs within the with block, the file is still automatically closed before the exception propagates.
#
# Improved Code Readability:
#
# By handling the setup and cleanup of resources implicitly, the with statement allows the programmer to focus on the core logic of file operations, leading to more concise and understandable code.
# In essence, the with statement provides a robust and convenient way to manage file resources, promoting safer and more efficient file handling practices in Python.
#
# 9:- What is the difference between multithreading and multiprocessing?
#
# Ans:-Multiprocessing and multithreading are both techniques used to achieve concurrency, but they differ in how they utilize system resources. Multiprocessing involves running multiple processes, each with its own memory space, on multiple CPU cores. This provides true parallelism and can significantly improve performance for CPU-bound tasks. Multithreading, on the other hand, involves running multiple threads within a single process, sharing the same memory space. While multithreading doesn't offer true parallelism on a single CPU core (due to the Global Interpreter Lock in Python, for example), it can improve responsiveness and efficiency for I/O-bound tasks.
#
# 10:- What are the advantages of using logging in a program?
#
# Ans:- Using logging in a program offers several significant advantages, primarily aiding in understanding, debugging, and maintaining software:
# Debugging and Troubleshooting:
#
# Logging provides a detailed record of events, variable states, and execution flow within a program. This information is crucial for identifying the root cause of errors, unexpected behavior, or crashes, especially in complex systems where direct debugging might be difficult or impossible (e.g., in production environments).
#
# Monitoring and Performance Analysis:
#
# Logs can be used to track key performance indicators (KPIs), resource utilization, and system health over time. This allows for proactive identification of performance bottlenecks, slowdowns, or potential issues before they impact users.
#
# Security Auditing and Compliance:
#
# Logging can record security-sensitive events, such as login attempts, access to sensitive data, or configuration changes. This provides an audit trail for security investigations, helps detect unauthorized activity, and assists in meeting compliance requirements.
#
# Understanding Application Behavior:
#
# By logging various events and data points, developers can gain a deeper understanding of how their application behaves in different scenarios, how users interact with it, and how various components communicate. This insight can inform future development and optimization efforts.
#
# Post-Mortem Analysis:
#
# In the event of a system failure, logs provide invaluable data for performing a post-mortem analysis, helping to understand the sequence of events leading to the failure and preventing similar issues in the future.
# Separation of Concerns and Granular Control:
#
# Logging frameworks allow for different levels of log messages (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL), enabling developers to control the verbosity of logs and filter messages based on their severity or purpose. This allows for focused analysis without being overwhelmed by unnecessary information.
#
# 11:- What is memory management in Python?
#
# Ans:- Memory management in Python refers to the system Python uses to handle the allocation and deallocation of memory for objects and data structures during program execution. Unlike some other programming languages where memory management is a manual task for the programmer (e.g., C, C++), Python provides automatic memory management.
#
# The core components of Python's memory management are:
#
# Reference Counting:
#
# Each object in Python has a reference count, which tracks the number of references (variables or other objects) pointing to it.
#
# When an object is created, its reference count is initialized.
#
# The reference count increases when a new reference to the object is created (e.g., assigning it to another variable) and decreases when a reference is deleted or goes out of scope.
#
# When an object's reference count drops to zero, it means there are no longer any references to it, and the memory occupied by that object can be reclaimed.
#
# Garbage Collection (Generational Garbage Collector):
#
# While reference counting effectively handles most memory deallocation, it cannot detect and reclaim memory involved in reference cycles (where objects refer to each other, creating a circular dependency, even if no external references exist).
#
# Python's garbage collector is designed to address this issue. It periodically scans for and collects objects that are part of reference cycles but are no longer reachable from the program's root objects (e.g., global variables, active function call frames).
#
# The garbage collector uses a generational approach, dividing objects into "generations" based on their age. Newer objects are in younger generations, and older, more stable objects are in older generations. This approach optimizes collection efforts by prioritizing younger generations, as they are more likely to contain short-lived objects.
#
# In essence, Python's memory management system automatically handles the complexities of memory allocation and deallocation, freeing developers from manual memory management and reducing the risk of memory-related errors.
#
# 12:-What are the basic steps involved in exception handling in Python?
#
# Ans:- The basic steps involved in exception handling in Python using try, except, else, and finally blocks are as follows:
#
# try Block:
#
# This block contains the code that is anticipated to potentially raise an exception. The Python interpreter attempts to execute the code within this block. If an exception occurs during the execution of the try block, the remaining code within the try block is skipped, and control is immediately transferred to the corresponding except block.
#
# except Block(s):
#
# These blocks are used to catch and handle specific exceptions that might be raised in the try block. You can specify a particular exception type to catch (e.g., ValueError, ZeroDivisionError), or use a general except block to catch any exception if no specific type is mentioned. When an exception occurs in the try block, Python searches for an except block that can handle that specific exception type. The code within the matching except block is then executed.
#
# else Block (Optional):
#
# This block contains code that will only be executed if no exception occurs within the try block. It provides a way to separate code that should run only when the try block executes successfully, without any exceptions.
#
# finally Block (Optional):
#
# This block contains code that will always be executed, regardless of whether an exception occurred in the try block or was handled by an except block. The finally block is typically used for cleanup operations, such as closing files or releasing resources, ensuring these actions are performed even if an error occurs.
#
# 13:= Why is memory management important in Python?
#
# Ans:- Memory management is important in Python for several key reasons, despite Python's automatic memory management features:
#
# Performance Optimization:
#
# Efficient memory usage directly impacts the speed and responsiveness of Python applications. Understanding how Python manages memory allows developers to write code that minimizes memory consumption and reduces overhead associated with memory allocation and deallocation, leading to faster execution.
#
# Preventing Memory Leaks:
#
# While Python's garbage collector handles automatic memory reclamation, situations like circular references can prevent objects from being deallocated, leading to memory leaks. Understanding memory management helps identify and address such issues, ensuring the program doesn't continuously consume more memory than necessary, which can lead to performance degradation or even crashes.
#
# Resource Management:
#
# Proper memory management ensures that your Python application utilizes system resources effectively. This is crucial for applications running on systems with limited memory or those requiring high performance, as it prevents excessive memory usage that could impact other processes or the overall system stability.
#
# Debugging and Troubleshooting:
#
# Knowledge of Python's memory management mechanisms (like reference counting and garbage collection) is invaluable for debugging memory-related issues. When an application exhibits unexpected memory growth or crashes due to memory exhaustion, understanding how memory is handled helps pinpoint the root cause and implement effective solutions.
#
# Writing Efficient Code:
#
# While Python abstracts away explicit memory management, being aware of memory implications can guide choices in data structures and algorithms.
#
# For example, using memory-efficient data structures or optimizing operations that create many temporary objects can significantly improve a program's overall efficiency.
#
# 14:- What is the role of try and except in exception handling?
#
# Ans:- The try and except statements are fundamental components of exception handling in programming, particularly in languages like Python. Their primary role is to manage and respond to errors that occur during program execution, preventing abrupt program termination and allowing for more robust and user-friendly applications.
#
# try block:
#
# The try block encloses the code that is susceptible to raising an exception. The program attempts to execute the code within this block. If no exception occurs during the execution of the try block, the except block is skipped.
#
# except block:
#
# The except block defines the code to be executed when a specific exception (or any exception if no specific type is mentioned) is raised within the corresponding try block. When an exception occurs in the try block, the program flow immediately jumps to the except block, and the code within it is executed to handle the error. This allows for graceful error recovery, such as displaying informative error messages, logging the error, or attempting alternative actions.
#
# In essence:
#
# The try block attempts to execute a potentially problematic section of code, and the except block catches and handles any exceptions that arise from that attempt, ensuring the program can continue running or respond in a controlled manner. This mechanism is crucial for building reliable software that can gracefully handle unexpected situations.
#
# 15:- F How does Python's garbage collection system work?
#
# Ans:- Python's garbage collection system employs a hybrid approach primarily relying on reference counting and a cyclic garbage collector to manage memory automatically.
#
# Reference Counting (Primary Mechanism):
#
# Every object in Python maintains a "reference count" that tracks how many references (variables, data structures, etc.) currently point to it.
#
# When an object is created, its reference count is initialized.
# When a new reference is made to an object (e.g., assigning it to another variable), its reference count increments.
#
# When a reference is removed (e.g., a variable goes out of scope, is deleted, or reassigned), the reference count decrements.
#
# If an object's reference count drops to zero, it signifies that no part of the program can access it, and the memory occupied by that object is immediately deallocated.
#
# Cyclic Garbage Collector (Addressing Circular References):
#
# Reference counting alone cannot handle "circular references," where two or more objects refer to each other in a cycle, preventing their reference counts from ever reaching zero, even if they are no longer reachable from the main program.
#
# The cyclic garbage collector periodically runs to detect and reclaim memory occupied by these unreachable circular references.
#
# It uses a mark-and-sweep algorithm or similar techniques to identify objects involved in cycles that are no longer accessible from the program's root objects.
#
# Once identified, the memory associated with these cyclic objects is reclaimed.
#
# The cyclic garbage collector also employs a generational approach, meaning it prioritizes collecting "younger" objects (those created more recently) as they are more likely to become unreachable quickly, while "older" objects are collected less frequently.
#
# 16:- What is the purpose of the else block in exception handling?
#
# Ans:- The purpose of the else block in exception handling (specifically in Python's try...except...else construct) is to execute code only if no exception occurs within the try block.
#
# Here's a breakdown of its function:
#
# Conditional Execution:
#
# The else block provides a clear way to define a block of code that should run exclusively when the code within the try block completes successfully, without raising any exceptions.
#
# Separation of Concerns:
#
# It helps in separating the "successful execution" logic from the "error handling" logic. Code that is part of the normal, non-error path can reside in the else block, making the try block more focused on the potentially problematic operations and the except blocks solely on handling specific errors.
#
# Preventing Accidental Exception Handling:
#
# By placing code that should only run on success in the else block, one avoids the risk of accidentally catching an exception raised by that success-related code within the except block, which is intended for exceptions from the try block itself.
#
# try:
#
#     # Code that might raise an exception
#     result = 10 / 2
# except ZeroDivisionError:
#
#     # Code to handle ZeroDivisionError
#     print("Error: Cannot divide by zero!")
# else:
#
#     # This code runs only if no exception occurred in the try block
#     print("Operation successful! Result:", result)
#
# 17:-  What are the common logging levels in Python?
#
# Ans:- Python's logging module provides several standard logging levels, each indicating a different severity of an event. These levels are used to categorize log messages and control which messages are processed and outputted. The common logging levels, in increasing order of severity, are:
#
# DEBUG:
#
# This level is used for detailed information, typically relevant only when diagnosing problems or during development. It includes fine-grained information about the application's internal state and execution flow.
#
# INFO:
#
# This level confirms that things are working as expected. It's used to log general information about the application's progress or significant events that indicate normal operation.
#
# WARNING:
#
# This level indicates that something unexpected happened or that a potential problem might occur in the near future, but the software is still functioning as expected. It's a sign that attention might be needed.
#
# ERROR:
#
# This level signifies a more serious problem that has prevented the software from performing some function. While the application might still be running, a specific operation or component has failed.
#
# CRITICAL:
#
# This level denotes a severe error, indicating that the program itself may be unable to continue running. It's used for critical failures that often lead to application termination or significant data loss.
# In addition to these, there is also the NOTSET level, which is the initial default setting for loggers and indicates that no specific level has been set.
#
# 18:- What is the difference between os.fork() and multiprocessing in Python?
#
# Ans:- The primary difference between os.fork() and Python's multiprocessing module lies in their level of abstraction and portability.
#
# os.fork():
#
# Low-level System Call:
#
# os.fork() is a direct wrapper around the Unix fork() system call. It creates a new process (child) that is an exact copy of the calling process (parent) at the moment of the call.
#
# Copy-on-Write:
#
# It utilizes a memory management technique called copy-on-write, where the parent and child processes initially share the same physical memory pages. A copy is only made when one of them modifies a shared page.
#
# Unix-specific:
#
# os.fork() is only available on Unix-like operating systems (Linux, macOS) and is not supported on Windows.
#
# Fine-grained Control:
#
# It offers lower-level control over process creation and resource sharing, but requires more manual handling of inter-process communication (IPC) and synchronization.
#
# Python's multiprocessing module:
#
# High-level Abstraction:
#
# The multiprocessing module provides a higher-level, more user-friendly interface for creating and managing processes in Python. It abstracts away the complexities of system calls.
#
# Platform Independent:
#
# It offers cross-platform compatibility, working on Windows, macOS, and Linux, by providing different "start methods" like fork, spawn, and forkserver.
#
# Built-in IPC:
#
# It includes built-in mechanisms for inter-process communication (e.g., Queue, Pipe, Manager) and synchronization (e.g., Lock, Semaphore), simplifying concurrent programming.
#
# Process Management:
#
# It provides classes like Process and Pool to manage process lifecycles and distribute tasks efficiently.
#
# In summary:
#
# os.fork() is a low-level, Unix-specific system call for process duplication, offering fine-grained control but requiring manual IPC.
# multiprocessing is a high-level, platform-independent Python module for concurrent programming with processes, providing built-in IPC and simplified process management. While multiprocessing can use fork as a start method on Unix, it offers a more robust and portable solution.
#
# 19:- What is the importance of closing a file in Python?
#
# Ans:- Closing a file in Python is important for several reasons:
#
# Resource Management and Prevention of Resource Leaks:
#
# When a file is opened, the operating system allocates resources (like memory buffers and file handles) to manage it. Failing to close a file explicitly means these resources are not immediately released, leading to potential resource leaks. In long-running applications or those handling many files, this can exhaust available file handles or memory, impacting system performance or even causing crashes.
#
# Data Integrity and Flushing Buffers:
#
# When writing to a file, data is often buffered in memory before being physically written to disk. Explicitly closing the file ensures that any remaining buffered data is flushed (written) to the file, guaranteeing data integrity and preventing data loss in case of program termination or system issues.
#
# Preventing File Locking Issues:
#
# In some operating systems, an open file might remain locked, preventing other processes or applications from accessing or modifying it. Closing the file releases this lock, allowing other programs to interact with it.
# Improved Code Maintainability and Robustness:
#
# Explicitly closing files makes the code more robust and easier to understand. It clearly indicates when resources are being properly managed, which is a good programming practice and helps in debugging potential issues related to file handling.
#
# Best Practice:
#
# The most recommended and Pythonic way to ensure files are closed properly, even in the presence of exceptions, is to use the with statement, also known as a context manager:
#
# try:
#
#     with open("example.txt", "w") as file:
#         file.write("This is some example text.")
#
# except IOError as e:
#
#     print(f"An error occurred: {e}")
#
# The with statement automatically handles the closing of the file when the block is exited, regardless of whether it's a normal exit or due to an exception.
#
# 20:- What is the difference between file.read() and file.readline() in Python?
#
# Ans:-In Python, file.read() and file.readline() are methods used to read data from a file object, but they differ in how much data they retrieve:
#
# file.read():
#
# Reads the entire content of the file and returns it as a single string.
# If an optional size argument is provided, it reads up to size characters (or bytes in binary mode) from the file.
#
# Can be inefficient for very large files as it loads the entire file into memory.
#
# file.readline():
#
# Reads a single line from the file, including the newline character (\n) at the end (if present), and returns it as a string.
#
# Subsequent calls to readline() will read the next line in the file.
# More memory-efficient for large files as it processes data line by line.
#
# In summary:
#
# Use file.read() when you need the entire file content as a single string, or a specific number of characters from the beginning.
#
# Use file.readline() when you need to process a file line by line, which is typically more efficient for large files.
#
# 21:- What is the logging module in Python used for?
#
# Ans:- Logging in Python, facilitated by the built-in logging module, is a crucial practice for software development and operation. Its primary uses include:
#
# Debugging and Troubleshooting:
#
# Logging allows developers to record information about the program's execution flow, variable states, and potential errors. This provides a detailed trail that helps in identifying the root cause of issues, making debugging significantly more efficient than relying solely on print() statements.
#
# Monitoring and Performance Analysis:
#
# By logging key events, performance metrics, and resource usage, developers can monitor the health and efficiency of their applications in real-time or through historical analysis. This helps in identifying bottlenecks, performance degradation, and potential issues before they impact users.
#
# Auditing and Compliance:
#
# In applications requiring a record of specific actions or events (e.g., user logins, data modifications), logging provides an auditable trail for security, compliance, and accountability purposes.
#
# Understanding Application Behavior:
#
# Logging can capture information about user interactions, application usage patterns, and system events, providing valuable insights into how the application is being used and where improvements can be made.
#
# Alerting and Notification:
#
# Logs can be configured to trigger alerts or notifications when specific critical events or errors occur, enabling proactive response to issues and minimizing downtime.
#
# Structured Information Capture:
#
# Unlike simple print() statements, the logging module allows for structured logging with different log levels (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL), custom formatters, and various handlers to direct logs to different destinations (e.g., console, file, network, email). This provides greater control and flexibility in managing log output and analysis.
#
# 22:- What is the os module in Python used for in file handling?
#
# Ans:- The os module in Python provides a way to interact with the operating system, including a wide range of functionalities for file and directory handling. It acts as an interface between your Python program and the underlying operating system's file system.
#
# Here's how the os module is used in file handling:
#
# Directory Management:
#
# os.getcwd(): Returns the current working directory.
# os.chdir(path): Changes the current working directory to the specified path.
#
# os.mkdir(path): Creates a new directory at the specified path.
#
# os.rmdir(path): Removes an empty directory at the specified path.
#
# os.makedirs(path): Creates directories recursively, including any necessary parent directories.
#
# os.removedirs(path): Removes directories recursively, provided they are empty.
#
# os.listdir(path): Returns a list of all files and directories within the specified path.
#
# File Operations:
#
# os.remove(path): Deletes a file at the specified path.
#
# os.rename(src, dst): Renames a file or directory from src to dst.
#
# os.stat(path): Returns status information about a file or directory, including size, modification time, etc.
#
# os.link(src, dst): Creates a hard link to a file.
#
# os.symlink(src, dst): Creates a symbolic link to a file or directory.
# Path Manipulation (often used with os.path submodule):
#
# os.path.join(path1, path2, ...): Joins path components intelligently, handling separator differences across operating systems.
#
# os.path.exists(path): Checks if a path exists.
#
# os.path.isfile(path): Checks if a path refers to a regular file.
#
# os.path.isdir(path): Checks if a path refers to a directory.
#
# os.path.abspath(path): Returns the absolute path of a given path.
#
# os.path.basename(path): Returns the base name of a path (the file or directory name).
#
# os.path.dirname(path): Returns the directory name of a path.
#
# Permissions and Ownership:
#
# os.chmod(path, mode): Changes the permissions of a file or directory.
#
# os.chown(path, uid, gid): Changes the ownership of a file or directory.
#
# In essence, the os module enables Python programs to perform various system-level operations related to files and directories in a cross-platform compatible manner.
#
# 23:- What are the challenges associated with memory management in Python?
#
# Ans:- Python's automatic memory management, while simplifying development, presents several challenges:
#
# Memory Leaks:
#
# While Python uses automatic garbage collection, memory leaks can still occur, especially with circular references where objects reference each other, preventing their reference count from dropping to zero. This can lead to increased memory consumption over time.
#
# Memory Fragmentation:
#
# When objects are allocated and deallocated in a non-linear fashion, memory can become fragmented into small, non-contiguous blocks. This makes it difficult to allocate larger blocks, even if sufficient total free memory exists.
#
# High Memory Consumption:
#
# Compared to lower-level languages, Python can exhibit higher memory consumption due to its dynamic typing, object-oriented nature, and the overhead of the interpreter. This can be particularly noticeable when working with large datasets or memory-intensive applications.
#
# Performance Overhead of Garbage Collection:
#
# While the garbage collector automatically manages memory, its periodic execution, especially the cyclic garbage collector for circular references, introduces a performance overhead. This can lead to pauses or slower execution times in certain scenarios.
#
# Limited Manual Control:
#
# Python's automatic memory management reduces the need for manual memory handling but also limits the developer's ability to fine-tune memory allocation and deallocation strategies for specific performance optimizations.
#
# Memory Bloat:
#
# Applications can experience memory bloat if large amounts of data are loaded into memory and not released when no longer needed, or if inefficient data structures are used.
#
# Debugging Memory-Related Issues:
#
# Diagnosing and resolving memory leaks, fragmentation, or excessive memory usage can be challenging due to the abstract nature of Python's memory management. Tools and profiling techniques are often required to identify the root cause of these issues.
#
# 24:- How do you raise an exception manually in Python?
#
# Ans:- In Python, exceptions are manually raised using the raise statement. This allows developers to explicitly trigger an error condition at a specific point in the code, interrupting the normal flow of execution.
#
# The basic syntax for raising an exception is:
#
# raise ExceptionType("Optional error message")
#
# Here's how to use it:
#
# Specify the Exception Type: You can raise any built-in exception type (e.g., ValueError, TypeError, ZeroDivisionError) or a custom exception you've defined.
#
#     raise ValueError("Invalid input provided.")
#
# Provide an Optional Error Message: A string message can be included to provide more context about the error. This message will be displayed as part of the exception traceback.
#
#     raise ZeroDivisionError("Cannot divide by zero; denominator was 0.")
#
# Raising a Custom Exception: You can define your own exception classes by inheriting from Python's built-in Exception class (or a more specific built-in exception).
#
#     class CustomError(Exception):
#         pass
#
#     # ... later in the code
#     raise CustomError("Something went wrong in a custom way.")
#
# EXAMPLE:-
#
# def process_data(value):
#
#     if not isinstance(value, int):
#         raise TypeError("Input must be an integer.")
#     if value < 0:
#         raise ValueError("Input cannot be negative.")
#     print(f"Processing value: {value}")
#
# try:
#
#     process_data("abc")
# except TypeError as e:
#
#     print(f"Caught a TypeError: {e}")
#
# try:
#
#     process_data(-5)
# except ValueError as e:
#
#     print(f"Caught a ValueError: {e}")
#
# process_data(10)
#
# 25:- Why is it important to use multithreading in certain applications?
#
# Ans:- Multithreading is crucial for applications that require high performance, responsiveness, and efficient resource utilization. By allowing multiple tasks to run concurrently within a single process, multithreading can significantly improve execution speed, especially on multi-core processors. This is because threads can execute tasks simultaneously, overlapping their execution and reducing overall processing time.
#
# Here's a more detailed look at why multithreading is important:
#
# 1. Improved Performance and Responsiveness:
#
# Parallel Execution:
#
# Multithreading enables true parallelism, allowing different parts of an application to run simultaneously on multiple processor cores. This can dramatically reduce the time it takes to complete complex tasks.
#
# Reduced Response Time:
#
# By handling tasks concurrently, multithreading can prevent a single long-running task from blocking the entire application, leading to a more responsive user interface and faster overall performance.
#
# Efficient Resource Utilization:
#
# Multithreading allows applications to utilize system resources more effectively by distributing tasks across available cores and preventing idle time.
#
# 2. Enhanced Concurrency and Scalability:
#
# Concurrent Task Handling:
#
# Multithreading allows applications to handle multiple requests or operations simultaneously, making it ideal for server applications, web browsers, and other environments where concurrency is essential.
#
# Scalability:
#
# As the number of users or tasks increases, multithreading allows applications to scale by utilizing more processor cores, making it easier to handle growing workloads.
#
# 3. Simplified Coding in Certain Scenarios:
#
# Remote Procedure Calls (RPCs):
#
# In some cases, multithreading can simplify the development of RPCs by allowing each call to be handled in its own thread.
#
# Conversational Servers:
#
# Multithreading can be particularly useful for conversational servers, where each client connection can be handled by a dedicated thread, improving efficiency and resource management.
#
# Examples of Applications Benefiting from Multithreading:
#
# Web Servers: Handling multiple client requests simultaneously.
#
# Web Browsers: Managing multiple tabs and background processes.
#
# Multimedia Applications: Processing audio and video data in parallel.
#
# Scientific Computing: Parallelizing complex simulations and calculations.
#
# Real-time Systems: Ensuring timely execution of critical tasks.
#
# In essence, multithreading is a powerful technique for improving the performance, responsiveness, and scalability of applications that need to handle multiple tasks concurrently. By allowing tasks to run in parallel, it can significantly reduce processing time and improve the overall user experience.

# %% [markdown]
# ***********************Practical Questions************************

# %%
# 1:-How can you open a file for writing in Python and write a string to it
# Step 1: Write to the file
with open('sample.txt', 'w') as file:
    file.write('Hello, Python!')

# Step 2: Read from the file
with open('sample.txt', 'r') as file:
    content = file.read()
    print('File content:', content)
# Out:
# File content: Hello, Python!

# %%
# 2:- Write a Python program to read the contents of a file and print each line
# Create and write to the file first (for demonstration)
with open('myfile.txt', 'w') as file:
    file.write('Line 1\n')
    file.write('Line 2\n')
    file.write('Line 3\n')

# Now read and print each line from the file
with open('myfile.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# Line 1
# Line 2
# Line 3

# %%
# 3:-  How would you handle a case where the file doesn't exist while trying to open it for reading?
try:
    with open('nonexistent.txt', 'r') as file:
        for line in file:
            print(line.strip())
except FileNotFoundError:
    print("Error: The file does not exist.")
# Out:
# Error: The file does not exist.

# %%
# 4:- Write a Python script that reads from one file and writes its content to another file ?

# Read from source file and write to destination file

# Create a source file with some content (for demo purposes)
with open('source.txt', 'w') as source_file:
    source_file.write('This is line 1.\n')
    source_file.write('This is line 2.\n')

# Now copy the content to another file
with open('source.txt', 'r') as source, open('destination.txt', 'w') as destination:
    for line in source:
        destination.write(line)

print("File copied successfully.")
# Out:
# File copied successfully.

# %%
# 5:- How would you catch and handle division by zero error in Python?

try:
    numerator = 10
    denominator = 0
    result = numerator / denominator
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
# Out:
# Error: Cannot divide by zero.

# %%
""" 6:- Write a Python program that logs an error message to a log file when a division by zero exception occurs"""

import logging

# Configure the logging system
logging.basicConfig(filename='error_log.txt', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

try:
    a = 10
    b = 0
    result = a / b
except ZeroDivisionError as e:
    logging.error("Division by zero error: %s", e)
    print("An error occurred. Check the log file.")
# Out:
# ERROR:root:Division by zero error: division by zero
# An error occurred. Check the log file.

# %%
""" 7:-  How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?
import logging"""

# Configure logging
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,  # This sets the lowest-severity log level to capture
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Log messages of different severity levels
logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")

print("Logs have been written to 'app.log'")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message
# Logs have been written to 'app.log'

# %%
# 8:-  Write a program to handle a file opening error using exception handling?
try:
    # Try to open a file that may not exist
    with open('nonexistent_file.txt', 'r') as file:
        content = file.read()
        print(content)
except FileNotFoundError:
    print("Error: The file you are trying to open does not exist.")
# Out:
# Error: The file you are trying to open does not exist.

# %%
# 9:-  How can you read a file line by line and store its content in a list in Python?

lines = []
with open('myfile.txt', 'r') as file:
    for line in file:
        lines.append(line.rstrip('\n'))  # Remove the newline character

print(lines)
# Out:
# ['Line 1', 'Line 2', 'Line 3']

# %%
#10:- How can you append data to an existing file in Python?
# Append a line to the file
with open('myfile.txt', 'a') as file:
    file.write('Appended line.\n')

# Read and print the file content
with open('myfile.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Line 1
# Line 2
# Line 3
# Appended line.

# %%
"""Write a Python program that uses a try-except block to handle an error when attempting to access a
dictionary key that doesn't exist"""

my_dict = {'name': 'Alice', 'age': 25}

try:
    # Attempt to access a key that may not exist
    value = my_dict['address']
    print("Address:", value)
except KeyError:
    print("Error: The key 'address' does not exist in the dictionary.")
# Out:
# Error: The key 'address' does not exist in the dictionary.

# %%
""" 12:- Write a program that demonstrates using multiple except blocks to handle different types of exceptions"""

try:
    # Example inputs
    x = int(input("Enter a number: "))
    y = int(input("Enter another number: "))

    result = x / y
    print("Result:", result)

    # Accessing a list element
    my_list = [1, 2, 3]
    print("Accessing index 5:", my_list[5])

except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except ValueError:
    print("Error: Invalid input. Please enter a valid integer.")
except IndexError:
    print("Error: List index out of range.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Enter a number: 2
# Enter another number: 5
# Result: 0.4
# Error: List index out of range.

# %%
#13:- How would you check if a file exists before attempting to read it in Python?
import os

filename = 'testfile.txt'

if os.path.exists(filename):
    with open(filename, 'r') as file:
        print(file.read())
else:
    print(f"The file '{filename}' does not exist.")
# Out:
# The file 'testfile.txt' does not exist.

# %%
#14:-  Write a program that uses the logging module to log both informational and error messages
import logging

# Configure logging to write to a file with a specific format
logging.basicConfig(
    filename='app.log',
    level=logging.DEBUG,  # Capture all levels DEBUG and above
    format='%(asctime)s - %(levelname)s - %(message)s'
)

# Log an informational message
logging.info("This is an informational message.")

try:
    # Simulate an error (division by zero)
    result = 10 / 0
except ZeroDivisionError as e:
    # Log the error message
    logging.error(f"An error occurred: {e}")

print("Logging complete. Check 'app.log' for details.")
# Out:
# ERROR:root:An error occurred: division by zero
# Logging complete. Check 'app.log' for details.

# %%
#15:- Write a Python program that prints the content of a file and handles the case when the file is empty
filename = 'example.txt'

try:
    with open(filename, 'r') as file:
        content = file.read()
        if content:
            print("File content:")
            print(content)
        else:
            print("The file is empty.")
except FileNotFoundError:
    print(f"The file '{filename}' does not exist.")
# Out:
# The file 'example.txt' does not exist.

# %%
#16:-  Demonstrate how to use memory profiling to check the memory usage of a small program

from memory_profiler import profile

@profile
def allocate_memory():
    data = [x * 2 for x in range(100000)]
    return data

if __name__ == "__main__":
    allocate_memory()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4254556312.py in <cell line: 0>()
#       1 #16:-  Demonstrate how to use memory profiling to check the memory usage of a small program
#       2
# ----> 3 from memory_profiler import profile
#       4
#       5 @profile
#
# ModuleNotFoundError: No module named 'memory_profiler'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#17:- Write a Python program to create and write a list of numbers to a file, one number per line
numbers = [10, 20, 30, 40, 50]

with open('numbers.txt', 'w') as file:
    for number in numbers:
        file.write(str(number) + '\n')

print("Numbers have been written to 'numbers.txt'.")
# Out:
# Numbers have been written to 'numbers.txt'.

# %%
#18:- How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler

# Create logger
logger = logging.getLogger('MyLogger')
logger.setLevel(logging.DEBUG)

# Create a rotating file handler
handler = RotatingFileHandler(
    'my_log.log', maxBytes=1_000_000, backupCount=3
)
handler.setLevel(logging.DEBUG)

# Create a formatter and set it for the handler
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Add the handler to the logger
logger.addHandler(handler)

# Example usage
for i in range(10000):
    logger.debug(f"Log message number {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:MyLogger:Log message number 5000
# DEBUG:MyLogger:Log message number 5001
# DEBUG:MyLogger:Log message number 5002
# DEBUG:MyLogger:Log message number 5003
# DEBUG:MyLogger:Log message number 5004
# DEBUG:MyLogger:Log message number 5005
# DEBUG:MyLogger:Log message number 5006
# DEBUG:MyLogger:Log message number 5007
# DEBUG:MyLogger:Log message number 5008
# DEBUG:MyLogger:Log message number 5009
# DEBUG:MyLogger:Log message number 5010
# DEBUG:MyLogger:Log message number 5011
# DEBUG:MyLogger:Log message number 5012
# DEBUG:MyLogger:Log message number 5013
# DEBUG:MyLogger:Log message number 5014
# DEBUG:MyLogger:Log message number 5015
# DEBUG:MyLogger:Log message number 5016
# DEBUG:MyLogger:Log message number 5017
# DEBUG:MyLogger:Log message number 5018
# DEBUG:MyLogger:Log message number 5019
# DEBUG:MyLogger:Log message number 5020
# DEBUG:MyLogger:Log message number 5021
# DEBUG:MyLogger:Log message number 5022
# DEBUG:MyLogger:Log message number 5023
# DEBUG:MyLogger:Log message number 5024
# DEBUG:MyLogger:Log message number 5025
# DEBUG:MyLogger:Log message number 5026
# DEBUG:MyLogger:Log message number 5027
# DEBUG:MyLogger:Log message number 5028
# DEBUG:MyLogger:Log message number 5029
# DEBUG:MyLogger:Log message number 5030
# DEBUG:MyLogger:Log message number 5031
# DEBUG:MyLogger:Log message number 5032
# DEBUG:MyLogger:Log message number 5033
# DEBUG:MyLogger:Log message number 5034
# DEBUG:MyLogger:Log message number 5035
# DEBUG:MyLogger:Log message number 5036
# DEBUG:MyLogger:Log message number 5037
# DEBUG:MyLogger:Log message number 5038
# DEBUG:MyLogger:Log message number 5039
# DEBUG:MyLogger:Log message number 5040
# DEBUG:MyLogger:Log message number 5041
# DEBUG:MyLogger:Log message number 5042
# DEBUG:MyLogger:Log message number 5043
# DEBUG:MyLogger:Log message number 5044
# DEBUG:MyLogger:Log message number 5045
# DEBUG:MyLogger:Log message number 5046
# DEBUG:MyLogger:Log message number 5047
# DEBUG:MyLogger:Log message number 5048
# DEBUG:MyLogger:Log message number 5049
# DEBUG:MyLogger:Log message number 5050
# DEBUG:MyLogger:Log message number 5051
# DEBUG:MyLogger:Log message number 5052
# DEBUG:MyLogger:Log message number 5053
# DEBUG:MyLogger:Log message number 5054
# DEBUG:MyLogger:Log message number 5055
# DEBUG:MyLogger:Log message number 5056
# DEBUG:MyLogger:Log message number 5057
# DEBUG:MyLogger:Log message number 5058
# DEBUG:MyLogger:Log message number 5059
# DEBUG:MyLogger:Log message number 5060
# DEBUG:MyLogger:Log message number 5061
# DEBUG:MyLogger:Log message number 5062
# DEBUG:MyLogger:Log message number 5063
# DEBUG:MyLogger:Log message number 5064
# DEBUG:MyLogger:Log message number 5065
# DEBUG:MyLogger:Log message number 5066
# DEBUG:MyLogger:Log message number 5067
# DEBUG:MyLogger:Log message number 5068
# DEBUG:MyLogger:Log message number 5069
# DEBUG:MyLogger:Log message number 5070
# DEBUG:MyLogger:Log message number 5071
# DEBUG:MyLogger:Log message number 5072
# DEBUG:MyLogger:Log message number 5073
# DEBUG:MyLogger:Log message number 5074
# DEBUG:MyLogger:Log message number 5075
# DEBUG:MyLogger:Log message number 5076
# DEBUG:MyLogger:Log message number 5077
# DEBUG:MyLogger:Log message number 5078
# DEBUG:MyLogger:Log message number 5079
# DEBUG:MyLogger:Log message number 5080
# DEBUG:MyLogger:Log message number 5081
# DEBUG:MyLogger:Log message number 5082
# DEBUG:MyLogger:Log message number 5083
# DEBUG:MyLogger:Log message number 5084
# DEBUG:MyLogger:Log message number 5085
# DEBUG:MyLogger:Log message number 5086
# DEBUG:MyLogger:Log message number 5087
# DEBUG:MyLogger:Log message number 5088
# DEBUG:MyLogger:Log message number 5089
# DEBUG:MyLogger:Log message number 5090
# DEBUG:MyLogger:Log message number 5091
# DEBUG:MyLogger:Log message number 5092
# DEBUG:MyLogger:Log message number 5093
# DEBUG:MyLogger:Log message number 5094
# DEBUG:MyLogger:Log message number 5095
# DEBUG:MyLogger:Log message number 5096
# DEBUG:MyLogger:Log message number 5097
# DEBUG:MyLogger:Log message number 5098
# DEBUG:MyLogger:Log message number 5099
# DEBUG:MyLogger:Log message number 5100
# DEBUG:MyLogger:Log message number 5101
# DEBUG:MyLogger:Log message number 5102
# DEBUG:MyLogger:Log message number 5103
# DEBUG:MyLogger:Log message number 5104
# DEBUG:MyLogger:Log message number 5105
# DEBUG:MyLogger:Log message number 5106
# DEBUG:MyLogger:Log message number 5107
# DEBUG:MyLogger:Log message number 5108
# DEBUG:MyLogger:Log message number 5109
# DEBUG:MyLogger:Log message number 5110
# DEBUG:MyLogger:Log message number 5111
# DEBUG:MyLogger:Log message number 5112
# DEBUG:MyLogger:Log message number 5113
# DEBUG:MyLogger:Log message number 5114
# DEBUG:MyLogger:Log message number 5115
# DEBUG:MyLogger:Log message number 5116
# DEBUG:MyLogger:Log message number 5117
# DEBUG:MyLogger:Log message number 5118
# DEBUG:MyLogger:Log message number 5119
# DEBUG:MyLogger:Log message number 5120
# DEBUG:MyLogger:Log message number 5121
# DEBUG:MyLogger:Log message number 5122
# DEBUG:MyLogger:Log message number 5123
# DEBUG:MyLogger:Log message number 5124
# DEBUG:MyLogger:Log message number 5125
# DEBUG:MyLogger:Log message number 5126
# DEBUG:MyLogger:Log message number 5127
# DEBUG:MyLogger:Log message number 5128
# DEBUG:MyLogger:Log message number 5129
# DEBUG:MyLogger:Log message number 5130
# DEBUG:MyLogger:Log message number 5131
# DEBUG:MyLogger:Log message number 5132
# DEBUG:MyLogger:Log message number 5133
# DEBUG:MyLogger:Log message number 5134
# DEBUG:MyLogger:Log message number 5135
# DEBUG:MyLogger:Log message number 5136
# DEBUG:MyLogger:Log message number 5137
# DEBUG:MyLogger:Log message number 5138
# DEBUG:MyLogger:Log message number 5139
# DEBUG:MyLogger:Log message number 5140
# DEBUG:MyLogger:Log message number 5141
# DEBUG:MyLogger:Log message number 5142
# DEBUG:MyLogger:Log message number 5143
# DEBUG:MyLogger:Log message number 5144
# DEBUG:MyLogger:Log message number 5145
# DEBUG:MyLogger:Log message number 5146
# DEBUG:MyLogger:Log message number 5147
# DEBUG:MyLogger:Log message number 5148
# DEBUG:MyLogger:Log message number 5149
# DEBUG:MyLogger:Log message number 5150
# DEBUG:MyLogger:Log message number 5151
# DEBUG:MyLogger:Log message number 5152
# DEBUG:MyLogger:Log message number 5153
# DEBUG:MyLogger:Log message number 5154
# DEBUG:MyLogger:Log message number 5155
# DEBUG:MyLogger:Log message number 5156
# DEBUG:MyLogger:Log message number 5157
# DEBUG:MyLogger:Log message number 5158
# DEBUG:MyLogger:Log message number 5159
# DEBUG:MyLogger:Log message number 5160
# DEBUG:MyLogger:Log message number 5161
# DEBUG:MyLogger:Log message number 5162
# DEBUG:MyLogger:Log message number 5163
# DEBUG:MyLogger:Log message number 5164
# DEBUG:MyLogger:Log message number 5165
# DEBUG:MyLogger:Log message number 5166
# DEBUG:MyLogger:Log message number 5167
# DEBUG:MyLogger:Log message number 5168
# DEBUG:MyLogger:Log message number 5169
# DEBUG:MyLogger:Log message number 5170
# DEBUG:MyLogger:Log message number 5171
# DEBUG:MyLogger:Log message number 5172
# DEBUG:MyLogger:Log message number 5173
# DEBUG:MyLogger:Log message number 5174
# DEBUG:MyLogger:Log message number 5175
# DEBUG:MyLogger:Log message number 5176
# DEBUG:MyLogger:Log message number 5177
# DEBUG:MyLogger:Log message number 5178
# DEBUG:MyLogger:Log message number 5179
# DEBUG:MyLogger:Log message number 5180
# DEBUG:MyLogger:Log message number 5181
# DEBUG:MyLogger:Log message number 5182
# DEBUG:MyLogger:Log message number 5183
# DEBUG:MyLogger:Log message number 5184
# DEBUG:MyLogger:Log message number 5185
# DEBUG:MyLogger:Log message number 5186
# DEBUG:MyLogger:Log message number 5187
# DEBUG:MyLogger:Log message number 5188
# DEBUG:MyLogger:Log message number 5189
# DEBUG:MyLogger:Log message number 5190
# DEBUG:MyLogger:Log message number 5191
# DEBUG:MyLogger:Log message number 5192
# DEBUG:MyLogger:Log message number 5193
# DEBUG:MyLogger:Log message number 5194
# DEBUG:MyLogger:Log message number 5195
# DEBUG:MyLogger:Log message number 5196
# DEBUG:MyLogger:Log message number 5197
# DEBUG:MyLogger:Log message number 5198
# DEBUG:MyLogger:Log message number 5199
# DEBUG:MyLogger:Log message number 5200
# DEBUG:MyLogger:Log message number 5201
# DEBUG:MyLogger:Log message number 5202
# DEBUG:MyLogger:Log message number 5203
# DEBUG:MyLogger:Log message number 5204
# DEBUG:MyLogger:Log message number 5205
# DEBUG:MyLogger:Log message number 5206
# DEBUG:MyLogger:Log message number 5207
# DEBUG:MyLogger:Log message number 5208
# DEBUG:MyLogger:Log message number 5209
# DEBUG:MyLogger:Log message number 5210
# DEBUG:MyLogger:Log message number 5211
# DEBUG:MyLogger:Log message number 5212
# DEBUG:MyLogger:Log message number 5213
# DEBUG:MyLogger:Log message number 5214
# DEBUG:MyLogger:Log message number 5215
# DEBUG:MyLogger:Log message number 5216
# DEBUG:MyLogger:Log message number 5217
# DEBUG:MyLogger:Log message number 5218
# DEBUG:MyLogger:Log message number 5219
# DEBUG:MyLogger:Log message number 5220
# DEBUG:MyLogger:Log message number 5221
# DEBUG:MyLogger:Log message number 5222
# DEBUG:MyLogger:Log message number 5223
# DEBUG:MyLogger:Log message number 5224
# DEBUG:MyLogger:Log message number 5225
# DEBUG:MyLogger:Log message number 5226
# DEBUG:MyLogger:Log message number 5227
# DEBUG:MyLogger:Log message number 5228
# DEBUG:MyLogger:Log message number 5229
# DEBUG:MyLogger:Log message number 5230
# DEBUG:MyLogger:Log message number 5231
# DEBUG:MyLogger:Log message number 5232
# DEBUG:MyLogger:Log message number 5233
# DEBUG:MyLogger:Log message number 5234
# DEBUG:MyLogger:Log message number 5235
# DEBUG:MyLogger:Log message number 5236
# DEBUG:MyLogger:Log message number 5237
# DEBUG:MyLogger:Log message number 5238
# DEBUG:MyLogger:Log message number 5239
# DEBUG:MyLogger:Log message number 5240
# DEBUG:MyLogger:Log message number 5241
# DEBUG:MyLogger:Log message number 5242
# DEBUG:MyLogger:Log message number 5243
# DEBUG:MyLogger:Log message number 5244
# DEBUG:MyLogger:Log message number 5245
# DEBUG:MyLogger:Log message number 5246
# DEBUG:MyLogger:Log message number 5247
# DEBUG:MyLogger:Log message number 5248
# DEBUG:MyLogger:Log message number 5249
# DEBUG:MyLogger:Log message number 5250
# DEBUG:MyLogger:Log message number 5251
# DEBUG:MyLogger:Log message number 5252
# DEBUG:MyLogger:Log message number 5253
# DEBUG:MyLogger:Log message number 5254
# DEBUG:MyLogger:Log message number 5255
# DEBUG:MyLogger:Log message number 5256
# DEBUG:MyLogger:Log message number 5257
# DEBUG:MyLogger:Log message number 5258
# DEBUG:MyLogger:Log message number 5259
# DEBUG:MyLogger:Log message number 5260
# DEBUG:MyLogger:Log message number 5261
# DEBUG:MyLogger:Log message number 5262
# DEBUG:MyLogger:Log message number 5263
# DEBUG:MyLogger:Log message number 5264
# DEBUG:MyLogger:Log message number 5265
# DEBUG:MyLogger:Log message number 5266
# DEBUG:MyLogger:Log message number 5267
# DEBUG:MyLogger:Log message number 5268
# DEBUG:MyLogger:Log message number 5269
# DEBUG:MyLogger:Log message number 5270
# DEBUG:MyLogger:Log message number 5271
# DEBUG:MyLogger:Log message number 5272
# DEBUG:MyLogger:Log message number 5273
# DEBUG:MyLogger:Log message number 5274
# DEBUG:MyLogger:Log message number 5275
# DEBUG:MyLogger:Log message number 5276
# DEBUG:MyLogger:Log message number 5277
# DEBUG:MyLogger:Log message number 5278
# DEBUG:MyLogger:Log message number 5279
# DEBUG:MyLogger:Log message number 5280
# DEBUG:MyLogger:Log message number 5281
# DEBUG:MyLogger:Log message number 5282
# DEBUG:MyLogger:Log message number 5283
# DEBUG:MyLogger:Log message number 5284
# DEBUG:MyLogger:Log message number 5285
# DEBUG:MyLogger:Log message number 5286
# DEBUG:MyLogger:Log message number 5287
# DEBUG:MyLogger:Log message number 5288
# DEBUG:MyLogger:Log message number 5289
# DEBUG:MyLogger:Log message number 5290
# DEBUG:MyLogger:Log message number 5291
# DEBUG:MyLogger:Log message number 5292
# DEBUG:MyLogger:Log message number 5293
# DEBUG:MyLogger:Log message number 5294
# DEBUG:MyLogger:Log message number 5295
# DEBUG:MyLogger:Log message number 5296
# DEBUG:MyLogger:Log message number 5297
# DEBUG:MyLogger:Log message number 5298
# DEBUG:MyLogger:Log message number 5299
# DEBUG:MyLogger:Log message number 5300
# DEBUG:MyLogger:Log message number 5301
# DEBUG:MyLogger:Log message number 5302
# DEBUG:MyLogger:Log message number 5303
# DEBUG:MyLogger:Log message number 5304
# DEBUG:MyLogger:Log message number 5305
# DEBUG:MyLogger:Log message number 5306
# DEBUG:MyLogger:Log message number 5307
# DEBUG:MyLogger:Log message number 5308
# DEBUG:MyLogger:Log message number 5309
# DEBUG:MyLogger:Log message number 5310
# DEBUG:MyLogger:Log message number 5311
# DEBUG:MyLogger:Log message number 5312
# DEBUG:MyLogger:Log message number 5313
# DEBUG:MyLogger:Log message number 5314
# DEBUG:MyLogger:Log message number 5315
# DEBUG:MyLogger:Log message number 5316
# DEBUG:MyLogger:Log message number 5317
# DEBUG:MyLogger:Log message number 5318
# DEBUG:MyLogger:Log message number 5319
# DEBUG:MyLogger:Log message number 5320
# DEBUG:MyLogger:Log message number 5321
# DEBUG:MyLogger:Log message number 5322
# DEBUG:MyLogger:Log message number 5323
# DEBUG:MyLogger:Log message number 5324
# DEBUG:MyLogger:Log message number 5325
# DEBUG:MyLogger:Log message number 5326
# DEBUG:MyLogger:Log message number 5327
# DEBUG:MyLogger:Log message number 5328
# DEBUG:MyLogger:Log message number 5329
# DEBUG:MyLogger:Log message number 5330
# DEBUG:MyLogger:Log message number 5331
# DEBUG:MyLogger:Log message number 5332
# DEBUG:MyLogger:Log message number 5333
# DEBUG:MyLogger:Log message number 5334
# DEBUG:MyLogger:Log message number 5335
# DEBUG:MyLogger:Log message number 5336
# DEBUG:MyLogger:Log message number 5337
# DEBUG:MyLogger:Log message number 5338
# DEBUG:MyLogger:Log message number 5339
# DEBUG:MyLogger:Log message number 5340
# DEBUG:MyLogger:Log message number 5341
# DEBUG:MyLogger:Log message number 5342
# DEBUG:MyLogger:Log message number 5343
# DEBUG:MyLogger:Log message number 5344
# DEBUG:MyLogger:Log message number 5345
# DEBUG:MyLogger:Log message number 5346
# DEBUG:MyLogger:Log message number 5347
# DEBUG:MyLogger:Log message number 5348
# DEBUG:MyLogger:Log message number 5349
# DEBUG:MyLogger:Log message number 5350
# DEBUG:MyLogger:Log message number 5351
# DEBUG:MyLogger:Log message number 5352
# DEBUG:MyLogger:Log message number 5353
# DEBUG:MyLogger:Log message number 5354
# DEBUG:MyLogger:Log message number 5355
# DEBUG:MyLogger:Log message number 5356
# DEBUG:MyLogger:Log message number 5357
# DEBUG:MyLogger:Log message number 5358
# DEBUG:MyLogger:Log message number 5359
# DEBUG:MyLogger:Log message number 5360
# DEBUG:MyLogger:Log message number 5361
# DEBUG:MyLogger:Log message number 5362
# DEBUG:MyLogger:Log message number 5363
# DEBUG:MyLogger:Log message number 5364
# DEBUG:MyLogger:Log message number 5365
# DEBUG:MyLogger:Log message number 5366
# DEBUG:MyLogger:Log message number 5367
# DEBUG:MyLogger:Log message number 5368
# DEBUG:MyLogger:Log message number 5369
# DEBUG:MyLogger:Log message number 5370
# DEBUG:MyLogger:Log message number 5371
# DEBUG:MyLogger:Log message number 5372
# DEBUG:MyLogger:Log message number 5373
# DEBUG:MyLogger:Log message number 5374
# DEBUG:MyLogger:Log message number 5375
# DEBUG:MyLogger:Log message number 5376
# DEBUG:MyLogger:Log message number 5377
# DEBUG:MyLogger:Log message number 5378
# DEBUG:MyLogger:Log message number 5379
# DEBUG:MyLogger:Log message number 5380
# DEBUG:MyLogger:Log message number 5381
# DEBUG:MyLogger:Log message number 5382
# DEBUG:MyLogger:Log message number 5383
# DEBUG:MyLogger:Log message number 5384
# DEBUG:MyLogger:Log message number 5385
# DEBUG:MyLogger:Log message number 5386
# DEBUG:MyLogger:Log message number 5387
# DEBUG:MyLogger:Log message number 5388
# DEBUG:MyLogger:Log message number 5389
# DEBUG:MyLogger:Log message number 5390
# DEBUG:MyLogger:Log message number 5391
# DEBUG:MyLogger:Log message number 5392
# DEBUG:MyLogger:Log message number 5393
# DEBUG:MyLogger:Log message number 5394
# DEBUG:MyLogger:Log message number 5395
# DEBUG:MyLogger:Log message number 5396
# DEBUG:MyLogger:Log message number 5397
# DEBUG:MyLogger:Log message number 5398
# DEBUG:MyLogger:Log message number 5399
# DEBUG:MyLogger:Log message number 5400
# DEBUG:MyLogger:Log message number 5401
# DEBUG:MyLogger:Log message number 5402
# DEBUG:MyLogger:Log message number 5403
# DEBUG:MyLogger:Log message number 5404
# DEBUG:MyLogger:Log message number 5405
# DEBUG:MyLogger:Log message number 5406
# DEBUG:MyLogger:Log message number 5407
# DEBUG:MyLogger:Log message number 5408
# DEBUG:MyLogger:Log message number 5409
# DEBUG:MyLogger:Log message number 5410
# DEBUG:MyLogger:Log message number 5411
# DEBUG:MyLogger:Log message number 5412
# DEBUG:MyLogger:Log message number 5413
# DEBUG:MyLogger:Log message number 5414
# DEBUG:MyLogger:Log message number 5415
# DEBUG:MyLogger:Log message number 5416
# DEBUG:MyLogger:Log message number 5417
# DEBUG:MyLogger:Log message number 5418
# DEBUG:MyLogger:Log message number 5419
# DEBUG:MyLogger:Log message number 5420
# DEBUG:MyLogger:Log message number 5421
# DEBUG:MyLogger:Log message number 5422
# DEBUG:MyLogger:Log message number 5423
# DEBUG:MyLogger:Log message number 5424
# DEBUG:MyLogger:Log message number 5425
# DEBUG:MyLogger:Log message number 5426
# DEBUG:MyLogger:Log message number 5427
# DEBUG:MyLogger:Log message number 5428
# DEBUG:MyLogger:Log message number 5429
# DEBUG:MyLogger:Log message number 5430
# DEBUG:MyLogger:Log message number 5431
# DEBUG:MyLogger:Log message number 5432
# DEBUG:MyLogger:Log message number 5433
# DEBUG:MyLogger:Log message number 5434
# DEBUG:MyLogger:Log message number 5435
# DEBUG:MyLogger:Log message number 5436
# DEBUG:MyLogger:Log message number 5437
# DEBUG:MyLogger:Log message number 5438
# DEBUG:MyLogger:Log message number 5439
# DEBUG:MyLogger:Log message number 5440
# DEBUG:MyLogger:Log message number 5441
# DEBUG:MyLogger:Log message number 5442
# DEBUG:MyLogger:Log message number 5443
# DEBUG:MyLogger:Log message number 5444
# DEBUG:MyLogger:Log message number 5445
# DEBUG:MyLogger:Log message number 5446
# DEBUG:MyLogger:Log message number 5447
# DEBUG:MyLogger:Log message number 5448
# DEBUG:MyLogger:Log message number 5449
# DEBUG:MyLogger:Log message number 5450
# DEBUG:MyLogger:Log message number 5451
# DEBUG:MyLogger:Log message number 5452
# DEBUG:MyLogger:Log message number 5453
# DEBUG:MyLogger:Log message number 5454
# DEBUG:MyLogger:Log message number 5455
# DEBUG:MyLogger:Log message number 5456
# DEBUG:MyLogger:Log message number 5457
# DEBUG:MyLogger:Log message number 5458
# DEBUG:MyLogger:Log message number 5459
# DEBUG:MyLogger:Log message number 5460
# DEBUG:MyLogger:Log message number 5461
# DEBUG:MyLogger:Log message number 5462
# DEBUG:MyLogger:Log message number 5463
# DEBUG:MyLogger:Log message number 5464
# DEBUG:MyLogger:Log message number 5465
# DEBUG:MyLogger:Log message number 5466
# DEBUG:MyLogger:Log message number 5467
# DEBUG:MyLogger:Log message number 5468
# DEBUG:MyLogger:Log message number 5469
# DEBUG:MyLogger:Log message number 5470
# DEBUG:MyLogger:Log message number 5471
# DEBUG:MyLogger:Log message number 5472
# DEBUG:MyLogger:Log message number 5473
# DEBUG:MyLogger:Log message number 5474
# DEBUG:MyLogger:Log message number 5475
# DEBUG:MyLogger:Log message number 5476
# DEBUG:MyLogger:Log message number 5477
# DEBUG:MyLogger:Log message number 5478
# DEBUG:MyLogger:Log message number 5479
# DEBUG:MyLogger:Log message number 5480
# DEBUG:MyLogger:Log message number 5481
# DEBUG:MyLogger:Log message number 5482
# DEBUG:MyLogger:Log message number 5483
# DEBUG:MyLogger:Log message number 5484
# DEBUG:MyLogger:Log message number 5485
# DEBUG:MyLogger:Log message number 5486
# DEBUG:MyLogger:Log message number 5487
# DEBUG:MyLogger:Log message number 5488
# DEBUG:MyLogger:Log message number 5489
# DEBUG:MyLogger:Log message number 5490
# DEBUG:MyLogger:Log message number 5491
# DEBUG:MyLogger:Log message number 5492
# DEBUG:MyLogger:Log message number 5493
# DEBUG:MyLogger:Log message number 5494
# DEBUG:MyLogger:Log message number 5495
# DEBUG:MyLogger:Log message number 5496
# DEBUG:MyLogger:Log message number 5497
# DEBUG:MyLogger:Log message number 5498
# DEBUG:MyLogger:Log message number 5499
# DEBUG:MyLogger:Log message number 5500
# DEBUG:MyLogger:Log message number 5501
# DEBUG:MyLogger:Log message number 5502
# DEBUG:MyLogger:Log message number 5503
# DEBUG:MyLogger:Log message number 5504
# DEBUG:MyLogger:Log message number 5505
# DEBUG:MyLogger:Log message number 5506
# DEBUG:MyLogger:Log message number 5507
# DEBUG:MyLogger:Log message number 5508
# DEBUG:MyLogger:Log message number 5509
# DEBUG:MyLogger:Log message number 5510
# DEBUG:MyLogger:Log message number 5511
# DEBUG:MyLogger:Log message number 5512
# DEBUG:MyLogger:Log message number 5513
# DEBUG:MyLogger:Log message number 5514
# DEBUG:MyLogger:Log message number 5515
# DEBUG:MyLogger:Log message number 5516
# DEBUG:MyLogger:Log message number 5517
# DEBUG:MyLogger:Log message number 5518
# DEBUG:MyLogger:Log message number 5519
# DEBUG:MyLogger:Log message number 5520
# DEBUG:MyLogger:Log message number 5521
# DEBUG:MyLogger:Log message number 5522
# DEBUG:MyLogger:Log message number 5523
# DEBUG:MyLogger:Log message number 5524
# DEBUG:MyLogger:Log message number 5525
# DEBUG:MyLogger:Log message number 5526
# DEBUG:MyLogger:Log message number 5527
# DEBUG:MyLogger:Log message number 5528
# DEBUG:MyLogger:Log message number 5529
# DEBUG:MyLogger:Log message number 5530
# DEBUG:MyLogger:Log message number 5531
# DEBUG:MyLogger:Log message number 5532
# DEBUG:MyLogger:Log message number 5533
# DEBUG:MyLogger:Log message number 5534
# DEBUG:MyLogger:Log message number 5535
# DEBUG:MyLogger:Log message number 5536
# DEBUG:MyLogger:Log message number 5537
# DEBUG:MyLogger:Log message number 5538
# DEBUG:MyLogger:Log message number 5539
# DEBUG:MyLogger:Log message number 5540
# DEBUG:MyLogger:Log message number 5541
# DEBUG:MyLogger:Log message number 5542
# DEBUG:MyLogger:Log message number 5543
# DEBUG:MyLogger:Log message number 5544
# DEBUG:MyLogger:Log message number 5545
# DEBUG:MyLogger:Log message number 5546
# DEBUG:MyLogger:Log message number 5547
# DEBUG:MyLogger:Log message number 5548
# DEBUG:MyLogger:Log message number 5549
# DEBUG:MyLogger:Log message number 5550
# DEBUG:MyLogger:Log message number 5551
# DEBUG:MyLogger:Log message number 5552
# DEBUG:MyLogger:Log message number 5553
# DEBUG:MyLogger:Log message number 5554
# DEBUG:MyLogger:Log message number 5555
# DEBUG:MyLogger:Log message number 5556
# DEBUG:MyLogger:Log message number 5557
# DEBUG:MyLogger:Log message number 5558
# DEBUG:MyLogger:Log message number 5559
# DEBUG:MyLogger:Log message number 5560
# DEBUG:MyLogger:Log message number 5561
# DEBUG:MyLogger:Log message number 5562
# DEBUG:MyLogger:Log message number 5563
# DEBUG:MyLogger:Log message number 5564
# DEBUG:MyLogger:Log message number 5565
# DEBUG:MyLogger:Log message number 5566
# DEBUG:MyLogger:Log message number 5567
# DEBUG:MyLogger:Log message number 5568
# DEBUG:MyLogger:Log message number 5569
# DEBUG:MyLogger:Log message number 5570
# DEBUG:MyLogger:Log message number 5571
# DEBUG:MyLogger:Log message number 5572
# DEBUG:MyLogger:Log message number 5573
# DEBUG:MyLogger:Log message number 5574
# DEBUG:MyLogger:Log message number 5575
# DEBUG:MyLogger:Log message number 5576
# DEBUG:MyLogger:Log message number 5577
# DEBUG:MyLogger:Log message number 5578
# DEBUG:MyLogger:Log message number 5579
# DEBUG:MyLogger:Log message number 5580
# DEBUG:MyLogger:Log message number 5581
# DEBUG:MyLogger:Log message number 5582
# DEBUG:MyLogger:Log message number 5583
# DEBUG:MyLogger:Log message number 5584
# DEBUG:MyLogger:Log message number 5585
# DEBUG:MyLogger:Log message number 5586
# DEBUG:MyLogger:Log message number 5587
# DEBUG:MyLogger:Log message number 5588
# DEBUG:MyLogger:Log message number 5589
# DEBUG:MyLogger:Log message number 5590
# DEBUG:MyLogger:Log message number 5591
# DEBUG:MyLogger:Log message number 5592
# DEBUG:MyLogger:Log message number 5593
# DEBUG:MyLogger:Log message number 5594
# DEBUG:MyLogger:Log message number 5595
# DEBUG:MyLogger:Log message number 5596
# DEBUG:MyLogger:Log message number 5597
# DEBUG:MyLogger:Log message number 5598
# DEBUG:MyLogger:Log message number 5599
# DEBUG:MyLogger:Log message number 5600
# DEBUG:MyLogger:Log message number 5601
# DEBUG:MyLogger:Log message number 5602
# DEBUG:MyLogger:Log message number 5603
# DEBUG:MyLogger:Log message number 5604
# DEBUG:MyLogger:Log message number 5605
# DEBUG:MyLogger:Log message number 5606
# DEBUG:MyLogger:Log message number 5607
# DEBUG:MyLogger:Log message number 5608
# DEBUG:MyLogger:Log message number 5609
# DEBUG:MyLogger:Log message number 5610
# DEBUG:MyLogger:Log message number 5611
# DEBUG:MyLogger:Log message number 5612
# DEBUG:MyLogger:Log message number 5613
# DEBUG:MyLogger:Log message number 5614
# DEBUG:MyLogger:Log message number 5615
# DEBUG:MyLogger:Log message number 5616
# DEBUG:MyLogger:Log message number 5617
# DEBUG:MyLogger:Log message number 5618
# DEBUG:MyLogger:Log message number 5619
# DEBUG:MyLogger:Log message number 5620
# DEBUG:MyLogger:Log message number 5621
# DEBUG:MyLogger:Log message number 5622
# DEBUG:MyLogger:Log message number 5623
# DEBUG:MyLogger:Log message number 5624
# DEBUG:MyLogger:Log message number 5625
# DEBUG:MyLogger:Log message number 5626
# DEBUG:MyLogger:Log message number 5627
# DEBUG:MyLogger:Log message number 5628
# DEBUG:MyLogger:Log message number 5629
# DEBUG:MyLogger:Log message number 5630
# DEBUG:MyLogger:Log message number 5631
# DEBUG:MyLogger:Log message number 5632
# DEBUG:MyLogger:Log message number 5633
# DEBUG:MyLogger:Log message number 5634
# DEBUG:MyLogger:Log message number 5635
# DEBUG:MyLogger:Log message number 5636
# DEBUG:MyLogger:Log message number 5637
# DEBUG:MyLogger:Log message number 5638
# DEBUG:MyLogger:Log message number 5639
# DEBUG:MyLogger:Log message number 5640
# DEBUG:MyLogger:Log message number 5641
# DEBUG:MyLogger:Log message number 5642
# DEBUG:MyLogger:Log message number 5643
# DEBUG:MyLogger:Log message number 5644
# DEBUG:MyLogger:Log message number 5645
# DEBUG:MyLogger:Log message number 5646
# DEBUG:MyLogger:Log message number 5647
# DEBUG:MyLogger:Log message number 5648
# DEBUG:MyLogger:Log message number 5649
# DEBUG:MyLogger:Log message number 5650
# DEBUG:MyLogger:Log message number 5651
# DEBUG:MyLogger:Log message number 5652
# DEBUG:MyLogger:Log message number 5653
# DEBUG:MyLogger:Log message number 5654
# DEBUG:MyLogger:Log message number 5655
# DEBUG:MyLogger:Log message number 5656
# DEBUG:MyLogger:Log message number 5657
# DEBUG:MyLogger:Log message number 5658
# DEBUG:MyLogger:Log message number 5659
# DEBUG:MyLogger:Log message number 5660
# DEBUG:MyLogger:Log message number 5661
# DEBUG:MyLogger:Log message number 5662
# DEBUG:MyLogger:Log message number 5663
# DEBUG:MyLogger:Log message number 5664
# DEBUG:MyLogger:Log message number 5665
# DEBUG:MyLogger:Log message number 5666
# DEBUG:MyLogger:Log message number 5667
# DEBUG:MyLogger:Log message number 5668
# DEBUG:MyLogger:Log message number 5669
# DEBUG:MyLogger:Log message number 5670
# DEBUG:MyLogger:Log message number 5671
# DEBUG:MyLogger:Log message number 5672
# DEBUG:MyLogger:Log message number 5673
# DEBUG:MyLogger:Log message number 5674
# DEBUG:MyLogger:Log message number 5675
# DEBUG:MyLogger:Log message number 5676
# DEBUG:MyLogger:Log message number 5677
# DEBUG:MyLogger:Log message number 5678
# DEBUG:MyLogger:Log message number 5679
# DEBUG:MyLogger:Log message number 5680
# DEBUG:MyLogger:Log message number 5681
# DEBUG:MyLogger:Log message number 5682
# DEBUG:MyLogger:Log message number 5683
# DEBUG:MyLogger:Log message number 5684
# DEBUG:MyLogger:Log message number 5685
# DEBUG:MyLogger:Log message number 5686
# DEBUG:MyLogger:Log message number 5687
# DEBUG:MyLogger:Log message number 5688
# DEBUG:MyLogger:Log message number 5689
# DEBUG:MyLogger:Log message number 5690
# DEBUG:MyLogger:Log message number 5691
# DEBUG:MyLogger:Log message number 5692
# DEBUG:MyLogger:Log message number 5693
# DEBUG:MyLogger:Log message number 5694
# DEBUG:MyLogger:Log message number 5695
# DEBUG:MyLogger:Log message number 5696
# DEBUG:MyLogger:Log message number 5697
# DEBUG:MyLogger:Log message number 5698
# DEBUG:MyLogger:Log message number 5699
# DEBUG:MyLogger:Log message number 5700
# DEBUG:MyLogger:Log message number 5701
# DEBUG:MyLogger:Log message number 5702
# DEBUG:MyLogger:Log message number 5703
# DEBUG:MyLogger:Log message number 5704
# DEBUG:MyLogger:Log message number 5705
# DEBUG:MyLogger:Log message number 5706
# DEBUG:MyLogger:Log message number 5707
# DEBUG:MyLogger:Log message number 5708
# DEBUG:MyLogger:Log message number 5709
# DEBUG:MyLogger:Log message number 5710
# DEBUG:MyLogger:Log message number 5711
# DEBUG:MyLogger:Log message number 5712
# DEBUG:MyLogger:Log message number 5713
# DEBUG:MyLogger:Log message number 5714
# DEBUG:MyLogger:Log message number 5715
# DEBUG:MyLogger:Log message number 5716
# DEBUG:MyLogger:Log message number 5717
# DEBUG:MyLogger:Log message number 5718
# DEBUG:MyLogger:Log message number 5719
# DEBUG:MyLogger:Log message number 5720
# DEBUG:MyLogger:Log message number 5721
# DEBUG:MyLogger:Log message number 5722
# DEBUG:MyLogger:Log message number 5723
# DEBUG:MyLogger:Log message number 5724
# DEBUG:MyLogger:Log message number 5725
# DEBUG:MyLogger:Log message number 5726
# DEBUG:MyLogger:Log message number 5727
# DEBUG:MyLogger:Log message number 5728
# DEBUG:MyLogger:Log message number 5729
# DEBUG:MyLogger:Log message number 5730
# DEBUG:MyLogger:Log message number 5731
# DEBUG:MyLogger:Log message number 5732
# DEBUG:MyLogger:Log message number 5733
# DEBUG:MyLogger:Log message number 5734
# DEBUG:MyLogger:Log message number 5735
# DEBUG:MyLogger:Log message number 5736
# DEBUG:MyLogger:Log message number 5737
# DEBUG:MyLogger:Log message number 5738
# DEBUG:MyLogger:Log message number 5739
# DEBUG:MyLogger:Log message number 5740
# DEBUG:MyLogger:Log message number 5741
# DEBUG:MyLogger:Log message number 5742
# DEBUG:MyLogger:Log message number 5743
# DEBUG:MyLogger:Log message number 5744
# DEBUG:MyLogger:Log message number 5745
# DEBUG:MyLogger:Log message number 5746
# DEBUG:MyLogger:Log message number 5747
# DEBUG:MyLogger:Log message number 5748
# DEBUG:MyLogger:Log message number 5749
# DEBUG:MyLogger:Log message number 5750
# DEBUG:MyLogger:Log message number 5751
# DEBUG:MyLogger:Log message number 5752
# DEBUG:MyLogger:Log message number 5753
# DEBUG:MyLogger:Log message number 5754
# DEBUG:MyLogger:Log message number 5755
# DEBUG:MyLogger:Log message number 5756
# DEBUG:MyLogger:Log message number 5757
# DEBUG:MyLogger:Log message number 5758
# DEBUG:MyLogger:Log message number 5759
# DEBUG:MyLogger:Log message number 5760
# DEBUG:MyLogger:Log message number 5761
# DEBUG:MyLogger:Log message number 5762
# DEBUG:MyLogger:Log message number 5763
# DEBUG:MyLogger:Log message number 5764
# DEBUG:MyLogger:Log message number 5765
# DEBUG:MyLogger:Log message number 5766
# DEBUG:MyLogger:Log message number 5767
# DEBUG:MyLogger:Log message number 5768
# DEBUG:MyLogger:Log message number 5769
# DEBUG:MyLogger:Log message number 5770
# DEBUG:MyLogger:Log message number 5771
# DEBUG:MyLogger:Log message number 5772
# DEBUG:MyLogger:Log message number 5773
# DEBUG:MyLogger:Log message number 5774
# DEBUG:MyLogger:Log message number 5775
# DEBUG:MyLogger:Log message number 5776
# DEBUG:MyLogger:Log message number 5777
# DEBUG:MyLogger:Log message number 5778
# DEBUG:MyLogger:Log message number 5779
# DEBUG:MyLogger:Log message number 5780
# DEBUG:MyLogger:Log message number 5781
# DEBUG:MyLogger:Log message number 5782
# DEBUG:MyLogger:Log message number 5783
# DEBUG:MyLogger:Log message number 5784
# DEBUG:MyLogger:Log message number 5785
# DEBUG:MyLogger:Log message number 5786
# DEBUG:MyLogger:Log message number 5787
# DEBUG:MyLogger:Log message number 5788
# DEBUG:MyLogger:Log message number 5789
# DEBUG:MyLogger:Log message number 5790
# DEBUG:MyLogger:Log message number 5791
# DEBUG:MyLogger:Log message number 5792
# DEBUG:MyLogger:Log message number 5793
# DEBUG:MyLogger:Log message number 5794
# DEBUG:MyLogger:Log message number 5795
# DEBUG:MyLogger:Log message number 5796
# DEBUG:MyLogger:Log message number 5797
# DEBUG:MyLogger:Log message number 5798
# DEBUG:MyLogger:Log message number 5799
# DEBUG:MyLogger:Log message number 5800
# DEBUG:MyLogger:Log message number 5801
# DEBUG:MyLogger:Log message number 5802
# DEBUG:MyLogger:Log message number 5803
# DEBUG:MyLogger:Log message number 5804
# DEBUG:MyLogger:Log message number 5805
# DEBUG:MyLogger:Log message number 5806
# DEBUG:MyLogger:Log message number 5807
# DEBUG:MyLogger:Log message number 5808
# DEBUG:MyLogger:Log message number 5809
# DEBUG:MyLogger:Log message number 5810
# DEBUG:MyLogger:Log message number 5811
# DEBUG:MyLogger:Log message number 5812
# DEBUG:MyLogger:Log message number 5813
# DEBUG:MyLogger:Log message number 5814
# DEBUG:MyLogger:Log message number 5815
# DEBUG:MyLogger:Log message number 5816
# DEBUG:MyLogger:Log message number 5817
# DEBUG:MyLogger:Log message number 5818
# DEBUG:MyLogger:Log message number 5819
# DEBUG:MyLogger:Log message number 5820
# DEBUG:MyLogger:Log message number 5821
# DEBUG:MyLogger:Log message number 5822
# DEBUG:MyLogger:Log message number 5823
# DEBUG:MyLogger:Log message number 5824
# DEBUG:MyLogger:Log message number 5825
# DEBUG:MyLogger:Log message number 5826
# DEBUG:MyLogger:Log message number 5827
# DEBUG:MyLogger:Log message number 5828
# DEBUG:MyLogger:Log message number 5829
# DEBUG:MyLogger:Log message number 5830
# DEBUG:MyLogger:Log message number 5831
# DEBUG:MyLogger:Log message number 5832
# DEBUG:MyLogger:Log message number 5833
# DEBUG:MyLogger:Log message number 5834
# DEBUG:MyLogger:Log message number 5835
# DEBUG:MyLogger:Log message number 5836
# DEBUG:MyLogger:Log message number 5837
# DEBUG:MyLogger:Log message number 5838
# DEBUG:MyLogger:Log message number 5839
# DEBUG:MyLogger:Log message number 5840
# DEBUG:MyLogger:Log message number 5841
# DEBUG:MyLogger:Log message number 5842
# DEBUG:MyLogger:Log message number 5843
# DEBUG:MyLogger:Log message number 5844
# DEBUG:MyLogger:Log message number 5845
# DEBUG:MyLogger:Log message number 5846
# DEBUG:MyLogger:Log message number 5847
# DEBUG:MyLogger:Log message number 5848
# DEBUG:MyLogger:Log message number 5849
# DEBUG:MyLogger:Log message number 5850
# DEBUG:MyLogger:Log message number 5851
# DEBUG:MyLogger:Log message number 5852
# DEBUG:MyLogger:Log message number 5853
# DEBUG:MyLogger:Log message number 5854
# DEBUG:MyLogger:Log message number 5855
# DEBUG:MyLogger:Log message number 5856
# DEBUG:MyLogger:Log message number 5857
# DEBUG:MyLogger:Log message number 5858
# DEBUG:MyLogger:Log message number 5859
# DEBUG:MyLogger:Log message number 5860
# DEBUG:MyLogger:Log message number 5861
# DEBUG:MyLogger:Log message number 5862
# DEBUG:MyLogger:Log message number 5863
# DEBUG:MyLogger:Log message number 5864
# DEBUG:MyLogger:Log message number 5865
# DEBUG:MyLogger:Log message number 5866
# DEBUG:MyLogger:Log message number 5867
# DEBUG:MyLogger:Log message number 5868
# DEBUG:MyLogger:Log message number 5869
# DEBUG:MyLogger:Log message number 5870
# DEBUG:MyLogger:Log message number 5871
# DEBUG:MyLogger:Log message number 5872
# DEBUG:MyLogger:Log message number 5873
# DEBUG:MyLogger:Log message number 5874
# DEBUG:MyLogger:Log message number 5875
# DEBUG:MyLogger:Log message number 5876
# DEBUG:MyLogger:Log message number 5877
# DEBUG:MyLogger:Log message number 5878
# DEBUG:MyLogger:Log message number 5879
# DEBUG:MyLogger:Log message number 5880
# DEBUG:MyLogger:Log message number 5881
# DEBUG:MyLogger:Log message number 5882
# DEBUG:MyLogger:Log message number 5883
# DEBUG:MyLogger:Log message number 5884
# DEBUG:MyLogger:Log message number 5885
# DEBUG:MyLogger:Log message number 5886
# DEBUG:MyLogger:Log message number 5887
# DEBUG:MyLogger:Log message number 5888
# DEBUG:MyLogger:Log message number 5889
# DEBUG:MyLogger:Log message number 5890
# DEBUG:MyLogger:Log message number 5891
# DEBUG:MyLogger:Log message number 5892
# DEBUG:MyLogger:Log message number 5893
# DEBUG:MyLogger:Log message number 5894
# DEBUG:MyLogger:Log message number 5895
# DEBUG:MyLogger:Log message number 5896
# DEBUG:MyLogger:Log message number 5897
# DEBUG:MyLogger:Log message number 5898
# DEBUG:MyLogger:Log message number 5899
# DEBUG:MyLogger:Log message number 5900
# DEBUG:MyLogger:Log message number 5901
# DEBUG:MyLogger:Log message number 5902
# DEBUG:MyLogger:Log message number 5903
# DEBUG:MyLogger:Log message number 5904
# DEBUG:MyLogger:Log message number 5905
# DEBUG:MyLogger:Log message number 5906
# DEBUG:MyLogger:Log message number 5907
# DEBUG:MyLogger:Log message number 5908
# DEBUG:MyLogger:Log message number 5909
# DEBUG:MyLogger:Log message number 5910
# DEBUG:MyLogger:Log message number 5911
# DEBUG:MyLogger:Log message number 5912
# DEBUG:MyLogger:Log message number 5913
# DEBUG:MyLogger:Log message number 5914
# DEBUG:MyLogger:Log message number 5915
# DEBUG:MyLogger:Log message number 5916
# DEBUG:MyLogger:Log message number 5917
# DEBUG:MyLogger:Log message number 5918
# DEBUG:MyLogger:Log message number 5919
# DEBUG:MyLogger:Log message number 5920
# DEBUG:MyLogger:Log message number 5921
# DEBUG:MyLogger:Log message number 5922
# DEBUG:MyLogger:Log message number 5923
# DEBUG:MyLogger:Log message number 5924
# DEBUG:MyLogger:Log message number 5925
# DEBUG:MyLogger:Log message number 5926
# DEBUG:MyLogger:Log message number 5927
# DEBUG:MyLogger:Log message number 5928
# DEBUG:MyLogger:Log message number 5929
# DEBUG:MyLogger:Log message number 5930
# DEBUG:MyLogger:Log message number 5931
# DEBUG:MyLogger:Log message number 5932
# DEBUG:MyLogger:Log message number 5933
# DEBUG:MyLogger:Log message number 5934
# DEBUG:MyLogger:Log message number 5935
# DEBUG:MyLogger:Log message number 5936
# DEBUG:MyLogger:Log message number 5937
# DEBUG:MyLogger:Log message number 5938
# DEBUG:MyLogger:Log message number 5939
# DEBUG:MyLogger:Log message number 5940
# DEBUG:MyLogger:Log message number 5941
# DEBUG:MyLogger:Log message number 5942
# DEBUG:MyLogger:Log message number 5943
# DEBUG:MyLogger:Log message number 5944
# DEBUG:MyLogger:Log message number 5945
# DEBUG:MyLogger:Log message number 5946
# DEBUG:MyLogger:Log message number 5947
# DEBUG:MyLogger:Log message number 5948
# DEBUG:MyLogger:Log message number 5949
# DEBUG:MyLogger:Log message number 5950
# DEBUG:MyLogger:Log message number 5951
# DEBUG:MyLogger:Log message number 5952
# DEBUG:MyLogger:Log message number 5953
# DEBUG:MyLogger:Log message number 5954
# DEBUG:MyLogger:Log message number 5955
# DEBUG:MyLogger:Log message number 5956
# DEBUG:MyLogger:Log message number 5957
# DEBUG:MyLogger:Log message number 5958
# DEBUG:MyLogger:Log message number 5959
# DEBUG:MyLogger:Log message number 5960
# DEBUG:MyLogger:Log message number 5961
# DEBUG:MyLogger:Log message number 5962
# DEBUG:MyLogger:Log message number 5963
# DEBUG:MyLogger:Log message number 5964
# DEBUG:MyLogger:Log message number 5965
# DEBUG:MyLogger:Log message number 5966
# DEBUG:MyLogger:Log message number 5967
# DEBUG:MyLogger:Log message number 5968
# DEBUG:MyLogger:Log message number 5969
# DEBUG:MyLogger:Log message number 5970
# DEBUG:MyLogger:Log message number 5971
# DEBUG:MyLogger:Log message number 5972
# DEBUG:MyLogger:Log message number 5973
# DEBUG:MyLogger:Log message number 5974
# DEBUG:MyLogger:Log message number 5975
# DEBUG:MyLogger:Log message number 5976
# DEBUG:MyLogger:Log message number 5977
# DEBUG:MyLogger:Log message number 5978
# DEBUG:MyLogger:Log message number 5979
# DEBUG:MyLogger:Log message number 5980
# DEBUG:MyLogger:Log message number 5981
# DEBUG:MyLogger:Log message number 5982
# DEBUG:MyLogger:Log message number 5983
# DEBUG:MyLogger:Log message number 5984
# DEBUG:MyLogger:Log message number 5985
# DEBUG:MyLogger:Log message number 5986
# DEBUG:MyLogger:Log message number 5987
# DEBUG:MyLogger:Log message number 5988
# DEBUG:MyLogger:Log message number 5989
# DEBUG:MyLogger:Log message number 5990
# DEBUG:MyLogger:Log message number 5991
# DEBUG:MyLogger:Log message number 5992
# DEBUG:MyLogger:Log message number 5993
# DEBUG:MyLogger:Log message number 5994
# DEBUG:MyLogger:Log message number 5995
# DEBUG:MyLogger:Log message number 5996
# DEBUG:MyLogger:Log message number 5997
# DEBUG:MyLogger:Log message number 5998
# DEBUG:MyLogger:Log message number 5999
# DEBUG:MyLogger:Log message number 6000
# DEBUG:MyLogger:Log message number 6001
# DEBUG:MyLogger:Log message number 6002
# DEBUG:MyLogger:Log message number 6003
# DEBUG:MyLogger:Log message number 6004
# DEBUG:MyLogger:Log message number 6005
# DEBUG:MyLogger:Log message number 6006
# DEBUG:MyLogger:Log message number 6007
# DEBUG:MyLogger:Log message number 6008
# DEBUG:MyLogger:Log message number 6009
# DEBUG:MyLogger:Log message number 6010
# DEBUG:MyLogger:Log message number 6011
# DEBUG:MyLogger:Log message number 6012
# DEBUG:MyLogger:Log message number 6013
# DEBUG:MyLogger:Log message number 6014
# DEBUG:MyLogger:Log message number 6015
# DEBUG:MyLogger:Log message number 6016
# DEBUG:MyLogger:Log message number 6017
# DEBUG:MyLogger:Log message number 6018
# DEBUG:MyLogger:Log message number 6019
# DEBUG:MyLogger:Log message number 6020
# DEBUG:MyLogger:Log message number 6021
# DEBUG:MyLogger:Log message number 6022
# DEBUG:MyLogger:Log message number 6023
# DEBUG:MyLogger:Log message number 6024
# DEBUG:MyLogger:Log message number 6025
# DEBUG:MyLogger:Log message number 6026
# DEBUG:MyLogger:Log message number 6027
# DEBUG:MyLogger:Log message number 6028
# DEBUG:MyLogger:Log message number 6029
# DEBUG:MyLogger:Log message number 6030
# DEBUG:MyLogger:Log message number 6031
# DEBUG:MyLogger:Log message number 6032
# DEBUG:MyLogger:Log message number 6033
# DEBUG:MyLogger:Log message number 6034
# DEBUG:MyLogger:Log message number 6035
# DEBUG:MyLogger:Log message number 6036
# DEBUG:MyLogger:Log message number 6037
# DEBUG:MyLogger:Log message number 6038
# DEBUG:MyLogger:Log message number 6039
# DEBUG:MyLogger:Log message number 6040
# DEBUG:MyLogger:Log message number 6041
# DEBUG:MyLogger:Log message number 6042
# DEBUG:MyLogger:Log message number 6043
# DEBUG:MyLogger:Log message number 6044
# DEBUG:MyLogger:Log message number 6045
# DEBUG:MyLogger:Log message number 6046
# DEBUG:MyLogger:Log message number 6047
# DEBUG:MyLogger:Log message number 6048
# DEBUG:MyLogger:Log message number 6049
# DEBUG:MyLogger:Log message number 6050
# DEBUG:MyLogger:Log message number 6051
# DEBUG:MyLogger:Log message number 6052
# DEBUG:MyLogger:Log message number 6053
# DEBUG:MyLogger:Log message number 6054
# DEBUG:MyLogger:Log message number 6055
# DEBUG:MyLogger:Log message number 6056
# DEBUG:MyLogger:Log message number 6057
# DEBUG:MyLogger:Log message number 6058
# DEBUG:MyLogger:Log message number 6059
# DEBUG:MyLogger:Log message number 6060
# DEBUG:MyLogger:Log message number 6061
# DEBUG:MyLogger:Log message number 6062
# DEBUG:MyLogger:Log message number 6063
# DEBUG:MyLogger:Log message number 6064
# DEBUG:MyLogger:Log message number 6065
# DEBUG:MyLogger:Log message number 6066
# DEBUG:MyLogger:Log message number 6067
# DEBUG:MyLogger:Log message number 6068
# DEBUG:MyLogger:Log message number 6069
# DEBUG:MyLogger:Log message number 6070
# DEBUG:MyLogger:Log message number 6071
# DEBUG:MyLogger:Log message number 6072
# DEBUG:MyLogger:Log message number 6073
# DEBUG:MyLogger:Log message number 6074
# DEBUG:MyLogger:Log message number 6075
# DEBUG:MyLogger:Log message number 6076
# DEBUG:MyLogger:Log message number 6077
# DEBUG:MyLogger:Log message number 6078
# DEBUG:MyLogger:Log message number 6079
# DEBUG:MyLogger:Log message number 6080
# DEBUG:MyLogger:Log message number 6081
# DEBUG:MyLogger:Log message number 6082
# DEBUG:MyLogger:Log message number 6083
# DEBUG:MyLogger:Log message number 6084
# DEBUG:MyLogger:Log message number 6085
# DEBUG:MyLogger:Log message number 6086
# DEBUG:MyLogger:Log message number 6087
# DEBUG:MyLogger:Log message number 6088
# DEBUG:MyLogger:Log message number 6089
# DEBUG:MyLogger:Log message number 6090
# DEBUG:MyLogger:Log message number 6091
# DEBUG:MyLogger:Log message number 6092
# DEBUG:MyLogger:Log message number 6093
# DEBUG:MyLogger:Log message number 6094
# DEBUG:MyLogger:Log message number 6095
# DEBUG:MyLogger:Log message number 6096
# DEBUG:MyLogger:Log message number 6097
# DEBUG:MyLogger:Log message number 6098
# DEBUG:MyLogger:Log message number 6099
# DEBUG:MyLogger:Log message number 6100
# DEBUG:MyLogger:Log message number 6101
# DEBUG:MyLogger:Log message number 6102
# DEBUG:MyLogger:Log message number 6103
# DEBUG:MyLogger:Log message number 6104
# DEBUG:MyLogger:Log message number 6105
# DEBUG:MyLogger:Log message number 6106
# DEBUG:MyLogger:Log message number 6107
# DEBUG:MyLogger:Log message number 6108
# DEBUG:MyLogger:Log message number 6109
# DEBUG:MyLogger:Log message number 6110
# DEBUG:MyLogger:Log message number 6111
# DEBUG:MyLogger:Log message number 6112
# DEBUG:MyLogger:Log message number 6113
# DEBUG:MyLogger:Log message number 6114
# DEBUG:MyLogger:Log message number 6115
# DEBUG:MyLogger:Log message number 6116
# DEBUG:MyLogger:Log message number 6117
# DEBUG:MyLogger:Log message number 6118
# DEBUG:MyLogger:Log message number 6119
# DEBUG:MyLogger:Log message number 6120
# DEBUG:MyLogger:Log message number 6121
# DEBUG:MyLogger:Log message number 6122
# DEBUG:MyLogger:Log message number 6123
# DEBUG:MyLogger:Log message number 6124
# DEBUG:MyLogger:Log message number 6125
# DEBUG:MyLogger:Log message number 6126
# DEBUG:MyLogger:Log message number 6127
# DEBUG:MyLogger:Log message number 6128
# DEBUG:MyLogger:Log message number 6129
# DEBUG:MyLogger:Log message number 6130
# DEBUG:MyLogger:Log message number 6131
# DEBUG:MyLogger:Log message number 6132
# DEBUG:MyLogger:Log message number 6133
# DEBUG:MyLogger:Log message number 6134
# DEBUG:MyLogger:Log message number 6135
# DEBUG:MyLogger:Log message number 6136
# DEBUG:MyLogger:Log message number 6137
# DEBUG:MyLogger:Log message number 6138
# DEBUG:MyLogger:Log message number 6139
# DEBUG:MyLogger:Log message number 6140
# DEBUG:MyLogger:Log message number 6141
# DEBUG:MyLogger:Log message number 6142
# DEBUG:MyLogger:Log message number 6143
# DEBUG:MyLogger:Log message number 6144
# DEBUG:MyLogger:Log message number 6145
# DEBUG:MyLogger:Log message number 6146
# DEBUG:MyLogger:Log message number 6147
# DEBUG:MyLogger:Log message number 6148
# DEBUG:MyLogger:Log message number 6149
# DEBUG:MyLogger:Log message number 6150
# DEBUG:MyLogger:Log message number 6151
# DEBUG:MyLogger:Log message number 6152
# DEBUG:MyLogger:Log message number 6153
# DEBUG:MyLogger:Log message number 6154
# DEBUG:MyLogger:Log message number 6155
# DEBUG:MyLogger:Log message number 6156
# DEBUG:MyLogger:Log message number 6157
# DEBUG:MyLogger:Log message number 6158
# DEBUG:MyLogger:Log message number 6159
# DEBUG:MyLogger:Log message number 6160
# DEBUG:MyLogger:Log message number 6161
# DEBUG:MyLogger:Log message number 6162
# DEBUG:MyLogger:Log message number 6163
# DEBUG:MyLogger:Log message number 6164
# DEBUG:MyLogger:Log message number 6165
# DEBUG:MyLogger:Log message number 6166
# DEBUG:MyLogger:Log message number 6167
# DEBUG:MyLogger:Log message number 6168
# DEBUG:MyLogger:Log message number 6169
# DEBUG:MyLogger:Log message number 6170
# DEBUG:MyLogger:Log message number 6171
# DEBUG:MyLogger:Log message number 6172
# DEBUG:MyLogger:Log message number 6173
# DEBUG:MyLogger:Log message number 6174
# DEBUG:MyLogger:Log message number 6175
# DEBUG:MyLogger:Log message number 6176
# DEBUG:MyLogger:Log message number 6177
# DEBUG:MyLogger:Log message number 6178
# DEBUG:MyLogger:Log message number 6179
# DEBUG:MyLogger:Log message number 6180
# DEBUG:MyLogger:Log message number 6181
# DEBUG:MyLogger:Log message number 6182
# DEBUG:MyLogger:Log message number 6183
# DEBUG:MyLogger:Log message number 6184
# DEBUG:MyLogger:Log message number 6185
# DEBUG:MyLogger:Log message number 6186
# DEBUG:MyLogger:Log message number 6187
# DEBUG:MyLogger:Log message number 6188
# DEBUG:MyLogger:Log message number 6189
# DEBUG:MyLogger:Log message number 6190
# DEBUG:MyLogger:Log message number 6191
# DEBUG:MyLogger:Log message number 6192
# DEBUG:MyLogger:Log message number 6193
# DEBUG:MyLogger:Log message number 6194
# DEBUG:MyLogger:Log message number 6195
# DEBUG:MyLogger:Log message number 6196
# DEBUG:MyLogger:Log message number 6197
# DEBUG:MyLogger:Log message number 6198
# DEBUG:MyLogger:Log message number 6199
# DEBUG:MyLogger:Log message number 6200
# DEBUG:MyLogger:Log message number 6201
# DEBUG:MyLogger:Log message number 6202
# DEBUG:MyLogger:Log message number 6203
# DEBUG:MyLogger:Log message number 6204
# DEBUG:MyLogger:Log message number 6205
# DEBUG:MyLogger:Log message number 6206
# DEBUG:MyLogger:Log message number 6207
# DEBUG:MyLogger:Log message number 6208
# DEBUG:MyLogger:Log message number 6209
# DEBUG:MyLogger:Log message number 6210
# DEBUG:MyLogger:Log message number 6211
# DEBUG:MyLogger:Log message number 6212
# DEBUG:MyLogger:Log message number 6213
# DEBUG:MyLogger:Log message number 6214
# DEBUG:MyLogger:Log message number 6215
# DEBUG:MyLogger:Log message number 6216
# DEBUG:MyLogger:Log message number 6217
# DEBUG:MyLogger:Log message number 6218
# DEBUG:MyLogger:Log message number 6219
# DEBUG:MyLogger:Log message number 6220
# DEBUG:MyLogger:Log message number 6221
# DEBUG:MyLogger:Log message number 6222
# DEBUG:MyLogger:Log message number 6223
# DEBUG:MyLogger:Log message number 6224
# DEBUG:MyLogger:Log message number 6225
# DEBUG:MyLogger:Log message number 6226
# DEBUG:MyLogger:Log message number 6227
# DEBUG:MyLogger:Log message number 6228
# ...
# DEBUG:MyLogger:Log message number 9590
# DEBUG:MyLogger:Log message number 9591
# DEBUG:MyLogger:Log message number 9592
# DEBUG:MyLogger:Log message number 9593
# DEBUG:MyLogger:Log message number 9594
# DEBUG:MyLogger:Log message number 9595
# DEBUG:MyLogger:Log message number 9596
# DEBUG:MyLogger:Log message number 9597
# DEBUG:MyLogger:Log message number 9598
# DEBUG:MyLogger:Log message number 9599
# DEBUG:MyLogger:Log message number 9600
# DEBUG:MyLogger:Log message number 9601
# DEBUG:MyLogger:Log message number 9602
# DEBUG:MyLogger:Log message number 9603
# DEBUG:MyLogger:Log message number 9604
# DEBUG:MyLogger:Log message number 9605
# DEBUG:MyLogger:Log message number 9606
# DEBUG:MyLogger:Log message number 9607
# DEBUG:MyLogger:Log message number 9608
# DEBUG:MyLogger:Log message number 9609
# DEBUG:MyLogger:Log message number 9610
# DEBUG:MyLogger:Log message number 9611
# DEBUG:MyLogger:Log message number 9612
# DEBUG:MyLogger:Log message number 9613
# DEBUG:MyLogger:Log message number 9614
# DEBUG:MyLogger:Log message number 9615
# DEBUG:MyLogger:Log message number 9616
# DEBUG:MyLogger:Log message number 9617
# DEBUG:MyLogger:Log message number 9618
# DEBUG:MyLogger:Log message number 9619
# DEBUG:MyLogger:Log message number 9620
# DEBUG:MyLogger:Log message number 9621
# DEBUG:MyLogger:Log message number 9622
# DEBUG:MyLogger:Log message number 9623
# DEBUG:MyLogger:Log message number 9624
# DEBUG:MyLogger:Log message number 9625
# DEBUG:MyLogger:Log message number 9626
# DEBUG:MyLogger:Log message number 9627
# DEBUG:MyLogger:Log message number 9628
# DEBUG:MyLogger:Log message number 9629
# DEBUG:MyLogger:Log message number 9630
# DEBUG:MyLogger:Log message number 9631
# DEBUG:MyLogger:Log message number 9632
# DEBUG:MyLogger:Log message number 9633
# DEBUG:MyLogger:Log message number 9634
# DEBUG:MyLogger:Log message number 9635
# DEBUG:MyLogger:Log message number 9636
# DEBUG:MyLogger:Log message number 9637
# DEBUG:MyLogger:Log message number 9638
# DEBUG:MyLogger:Log message number 9639
# DEBUG:MyLogger:Log message number 9640
# DEBUG:MyLogger:Log message number 9641
# DEBUG:MyLogger:Log message number 9642
# DEBUG:MyLogger:Log message number 9643
# DEBUG:MyLogger:Log message number 9644
# DEBUG:MyLogger:Log message number 9645
# DEBUG:MyLogger:Log message number 9646
# DEBUG:MyLogger:Log message number 9647
# DEBUG:MyLogger:Log message number 9648
# DEBUG:MyLogger:Log message number 9649
# DEBUG:MyLogger:Log message number 9650
# DEBUG:MyLogger:Log message number 9651
# DEBUG:MyLogger:Log message number 9652
# DEBUG:MyLogger:Log message number 9653
# DEBUG:MyLogger:Log message number 9654
# DEBUG:MyLogger:Log message number 9655
# DEBUG:MyLogger:Log message number 9656
# DEBUG:MyLogger:Log message number 9657
# DEBUG:MyLogger:Log message number 9658
# DEBUG:MyLogger:Log message number 9659
# DEBUG:MyLogger:Log message number 9660
# DEBUG:MyLogger:Log message number 9661
# DEBUG:MyLogger:Log message number 9662
# DEBUG:MyLogger:Log message number 9663
# DEBUG:MyLogger:Log message number 9664
# DEBUG:MyLogger:Log message number 9665
# DEBUG:MyLogger:Log message number 9666
# DEBUG:MyLogger:Log message number 9667
# DEBUG:MyLogger:Log message number 9668
# DEBUG:MyLogger:Log message number 9669
# DEBUG:MyLogger:Log message number 9670
# DEBUG:MyLogger:Log message number 9671
# DEBUG:MyLogger:Log message number 9672
# DEBUG:MyLogger:Log message number 9673
# DEBUG:MyLogger:Log message number 9674
# DEBUG:MyLogger:Log message number 9675
# DEBUG:MyLogger:Log message number 9676
# DEBUG:MyLogger:Log message number 9677
# DEBUG:MyLogger:Log message number 9678
# DEBUG:MyLogger:Log message number 9679
# DEBUG:MyLogger:Log message number 9680
# DEBUG:MyLogger:Log message number 9681
# DEBUG:MyLogger:Log message number 9682
# DEBUG:MyLogger:Log message number 9683
# DEBUG:MyLogger:Log message number 9684
# DEBUG:MyLogger:Log message number 9685
# DEBUG:MyLogger:Log message number 9686
# DEBUG:MyLogger:Log message number 9687
# DEBUG:MyLogger:Log message number 9688
# DEBUG:MyLogger:Log message number 9689
# DEBUG:MyLogger:Log message number 9690
# DEBUG:MyLogger:Log message number 9691
# DEBUG:MyLogger:Log message number 9692
# DEBUG:MyLogger:Log message number 9693
# DEBUG:MyLogger:Log message number 9694
# DEBUG:MyLogger:Log message number 9695
# DEBUG:MyLogger:Log message number 9696
# DEBUG:MyLogger:Log message number 9697
# DEBUG:MyLogger:Log message number 9698
# DEBUG:MyLogger:Log message number 9699
# DEBUG:MyLogger:Log message number 9700
# DEBUG:MyLogger:Log message number 9701
# DEBUG:MyLogger:Log message number 9702
# DEBUG:MyLogger:Log message number 9703
# DEBUG:MyLogger:Log message number 9704
# DEBUG:MyLogger:Log message number 9705
# DEBUG:MyLogger:Log message number 9706
# DEBUG:MyLogger:Log message number 9707
# DEBUG:MyLogger:Log message number 9708
# DEBUG:MyLogger:Log message number 9709
# DEBUG:MyLogger:Log message number 9710
# DEBUG:MyLogger:Log message number 9711
# DEBUG:MyLogger:Log message number 9712
# DEBUG:MyLogger:Log message number 9713
# DEBUG:MyLogger:Log message number 9714
# DEBUG:MyLogger:Log message number 9715
# DEBUG:MyLogger:Log message number 9716
# DEBUG:MyLogger:Log message number 9717
# DEBUG:MyLogger:Log message number 9718
# DEBUG:MyLogger:Log message number 9719
# DEBUG:MyLogger:Log message number 9720
# DEBUG:MyLogger:Log message number 9721
# DEBUG:MyLogger:Log message number 9722
# DEBUG:MyLogger:Log message number 9723
# DEBUG:MyLogger:Log message number 9724
# DEBUG:MyLogger:Log message number 9725
# DEBUG:MyLogger:Log message number 9726
# DEBUG:MyLogger:Log message number 9727
# DEBUG:MyLogger:Log message number 9728
# DEBUG:MyLogger:Log message number 9729
# DEBUG:MyLogger:Log message number 9730
# DEBUG:MyLogger:Log message number 9731
# DEBUG:MyLogger:Log message number 9732
# DEBUG:MyLogger:Log message number 9733
# DEBUG:MyLogger:Log message number 9734
# DEBUG:MyLogger:Log message number 9735
# DEBUG:MyLogger:Log message number 9736
# DEBUG:MyLogger:Log message number 9737
# DEBUG:MyLogger:Log message number 9738
# DEBUG:MyLogger:Log message number 9739
# DEBUG:MyLogger:Log message number 9740
# DEBUG:MyLogger:Log message number 9741
# DEBUG:MyLogger:Log message number 9742
# DEBUG:MyLogger:Log message number 9743
# DEBUG:MyLogger:Log message number 9744
# DEBUG:MyLogger:Log message number 9745
# DEBUG:MyLogger:Log message number 9746
# DEBUG:MyLogger:Log message number 9747
# DEBUG:MyLogger:Log message number 9748
# DEBUG:MyLogger:Log message number 9749
# DEBUG:MyLogger:Log message number 9750
# DEBUG:MyLogger:Log message number 9751
# DEBUG:MyLogger:Log message number 9752
# DEBUG:MyLogger:Log message number 9753
# DEBUG:MyLogger:Log message number 9754
# DEBUG:MyLogger:Log message number 9755
# DEBUG:MyLogger:Log message number 9756
# DEBUG:MyLogger:Log message number 9757
# DEBUG:MyLogger:Log message number 9758
# DEBUG:MyLogger:Log message number 9759
# DEBUG:MyLogger:Log message number 9760
# DEBUG:MyLogger:Log message number 9761
# DEBUG:MyLogger:Log message number 9762
# DEBUG:MyLogger:Log message number 9763
# DEBUG:MyLogger:Log message number 9764
# DEBUG:MyLogger:Log message number 9765
# DEBUG:MyLogger:Log message number 9766
# DEBUG:MyLogger:Log message number 9767
# DEBUG:MyLogger:Log message number 9768
# DEBUG:MyLogger:Log message number 9769
# DEBUG:MyLogger:Log message number 9770
# DEBUG:MyLogger:Log message number 9771
# DEBUG:MyLogger:Log message number 9772
# DEBUG:MyLogger:Log message number 9773
# DEBUG:MyLogger:Log message number 9774
# DEBUG:MyLogger:Log message number 9775
# DEBUG:MyLogger:Log message number 9776
# DEBUG:MyLogger:Log message number 9777
# DEBUG:MyLogger:Log message number 9778
# DEBUG:MyLogger:Log message number 9779
# DEBUG:MyLogger:Log message number 9780
# DEBUG:MyLogger:Log message number 9781
# DEBUG:MyLogger:Log message number 9782
# DEBUG:MyLogger:Log message number 9783
# DEBUG:MyLogger:Log message number 9784
# DEBUG:MyLogger:Log message number 9785
# DEBUG:MyLogger:Log message number 9786
# DEBUG:MyLogger:Log message number 9787
# DEBUG:MyLogger:Log message number 9788
# DEBUG:MyLogger:Log message number 9789
# DEBUG:MyLogger:Log message number 9790
# DEBUG:MyLogger:Log message number 9791
# DEBUG:MyLogger:Log message number 9792
# DEBUG:MyLogger:Log message number 9793
# DEBUG:MyLogger:Log message number 9794
# DEBUG:MyLogger:Log message number 9795
# DEBUG:MyLogger:Log message number 9796
# DEBUG:MyLogger:Log message number 9797
# DEBUG:MyLogger:Log message number 9798
# DEBUG:MyLogger:Log message number 9799
# DEBUG:MyLogger:Log message number 9800
# DEBUG:MyLogger:Log message number 9801
# DEBUG:MyLogger:Log message number 9802
# DEBUG:MyLogger:Log message number 9803
# DEBUG:MyLogger:Log message number 9804
# DEBUG:MyLogger:Log message number 9805
# DEBUG:MyLogger:Log message number 9806
# DEBUG:MyLogger:Log message number 9807
# DEBUG:MyLogger:Log message number 9808
# DEBUG:MyLogger:Log message number 9809
# DEBUG:MyLogger:Log message number 9810
# DEBUG:MyLogger:Log message number 9811
# DEBUG:MyLogger:Log message number 9812
# DEBUG:MyLogger:Log message number 9813
# DEBUG:MyLogger:Log message number 9814
# DEBUG:MyLogger:Log message number 9815
# DEBUG:MyLogger:Log message number 9816
# DEBUG:MyLogger:Log message number 9817
# DEBUG:MyLogger:Log message number 9818
# DEBUG:MyLogger:Log message number 9819
# DEBUG:MyLogger:Log message number 9820
# DEBUG:MyLogger:Log message number 9821
# DEBUG:MyLogger:Log message number 9822
# DEBUG:MyLogger:Log message number 9823
# DEBUG:MyLogger:Log message number 9824
# DEBUG:MyLogger:Log message number 9825
# DEBUG:MyLogger:Log message number 9826
# DEBUG:MyLogger:Log message number 9827
# DEBUG:MyLogger:Log message number 9828
# DEBUG:MyLogger:Log message number 9829
# DEBUG:MyLogger:Log message number 9830
# DEBUG:MyLogger:Log message number 9831
# DEBUG:MyLogger:Log message number 9832
# DEBUG:MyLogger:Log message number 9833
# DEBUG:MyLogger:Log message number 9834
# DEBUG:MyLogger:Log message number 9835
# DEBUG:MyLogger:Log message number 9836
# DEBUG:MyLogger:Log message number 9837
# DEBUG:MyLogger:Log message number 9838
# DEBUG:MyLogger:Log message number 9839
# DEBUG:MyLogger:Log message number 9840
# DEBUG:MyLogger:Log message number 9841
# DEBUG:MyLogger:Log message number 9842
# DEBUG:MyLogger:Log message number 9843
# DEBUG:MyLogger:Log message number 9844
# DEBUG:MyLogger:Log message number 9845
# DEBUG:MyLogger:Log message number 9846
# DEBUG:MyLogger:Log message number 9847
# DEBUG:MyLogger:Log message number 9848
# DEBUG:MyLogger:Log message number 9849
# DEBUG:MyLogger:Log message number 9850
# DEBUG:MyLogger:Log message number 9851
# DEBUG:MyLogger:Log message number 9852
# DEBUG:MyLogger:Log message number 9853
# DEBUG:MyLogger:Log message number 9854
# DEBUG:MyLogger:Log message number 9855
# DEBUG:MyLogger:Log message number 9856
# DEBUG:MyLogger:Log message number 9857
# DEBUG:MyLogger:Log message number 9858
# DEBUG:MyLogger:Log message number 9859
# DEBUG:MyLogger:Log message number 9860
# DEBUG:MyLogger:Log message number 9861
# DEBUG:MyLogger:Log message number 9862
# DEBUG:MyLogger:Log message number 9863
# DEBUG:MyLogger:Log message number 9864
# DEBUG:MyLogger:Log message number 9865
# DEBUG:MyLogger:Log message number 9866
# DEBUG:MyLogger:Log message number 9867
# DEBUG:MyLogger:Log message number 9868
# DEBUG:MyLogger:Log message number 9869
# DEBUG:MyLogger:Log message number 9870
# DEBUG:MyLogger:Log message number 9871
# DEBUG:MyLogger:Log message number 9872
# DEBUG:MyLogger:Log message number 9873
# DEBUG:MyLogger:Log message number 9874
# DEBUG:MyLogger:Log message number 9875
# DEBUG:MyLogger:Log message number 9876
# DEBUG:MyLogger:Log message number 9877
# DEBUG:MyLogger:Log message number 9878
# DEBUG:MyLogger:Log message number 9879
# DEBUG:MyLogger:Log message number 9880
# DEBUG:MyLogger:Log message number 9881
# DEBUG:MyLogger:Log message number 9882
# DEBUG:MyLogger:Log message number 9883
# DEBUG:MyLogger:Log message number 9884
# DEBUG:MyLogger:Log message number 9885
# DEBUG:MyLogger:Log message number 9886
# DEBUG:MyLogger:Log message number 9887
# DEBUG:MyLogger:Log message number 9888
# DEBUG:MyLogger:Log message number 9889
# DEBUG:MyLogger:Log message number 9890
# DEBUG:MyLogger:Log message number 9891
# DEBUG:MyLogger:Log message number 9892
# DEBUG:MyLogger:Log message number 9893
# DEBUG:MyLogger:Log message number 9894
# DEBUG:MyLogger:Log message number 9895
# DEBUG:MyLogger:Log message number 9896
# DEBUG:MyLogger:Log message number 9897
# DEBUG:MyLogger:Log message number 9898
# DEBUG:MyLogger:Log message number 9899
# DEBUG:MyLogger:Log message number 9900
# DEBUG:MyLogger:Log message number 9901
# DEBUG:MyLogger:Log message number 9902
# DEBUG:MyLogger:Log message number 9903
# DEBUG:MyLogger:Log message number 9904
# DEBUG:MyLogger:Log message number 9905
# DEBUG:MyLogger:Log message number 9906
# DEBUG:MyLogger:Log message number 9907
# DEBUG:MyLogger:Log message number 9908
# DEBUG:MyLogger:Log message number 9909
# DEBUG:MyLogger:Log message number 9910
# DEBUG:MyLogger:Log message number 9911
# DEBUG:MyLogger:Log message number 9912
# DEBUG:MyLogger:Log message number 9913
# DEBUG:MyLogger:Log message number 9914
# DEBUG:MyLogger:Log message number 9915
# DEBUG:MyLogger:Log message number 9916
# DEBUG:MyLogger:Log message number 9917
# DEBUG:MyLogger:Log message number 9918
# DEBUG:MyLogger:Log message number 9919
# DEBUG:MyLogger:Log message number 9920
# DEBUG:MyLogger:Log message number 9921
# DEBUG:MyLogger:Log message number 9922
# DEBUG:MyLogger:Log message number 9923
# DEBUG:MyLogger:Log message number 9924
# DEBUG:MyLogger:Log message number 9925
# DEBUG:MyLogger:Log message number 9926
# DEBUG:MyLogger:Log message number 9927
# DEBUG:MyLogger:Log message number 9928
# DEBUG:MyLogger:Log message number 9929
# DEBUG:MyLogger:Log message number 9930
# DEBUG:MyLogger:Log message number 9931
# DEBUG:MyLogger:Log message number 9932
# DEBUG:MyLogger:Log message number 9933
# DEBUG:MyLogger:Log message number 9934
# DEBUG:MyLogger:Log message number 9935
# DEBUG:MyLogger:Log message number 9936
# DEBUG:MyLogger:Log message number 9937
# DEBUG:MyLogger:Log message number 9938
# DEBUG:MyLogger:Log message number 9939
# DEBUG:MyLogger:Log message number 9940
# DEBUG:MyLogger:Log message number 9941
# DEBUG:MyLogger:Log message number 9942
# DEBUG:MyLogger:Log message number 9943
# DEBUG:MyLogger:Log message number 9944
# DEBUG:MyLogger:Log message number 9945
# DEBUG:MyLogger:Log message number 9946
# DEBUG:MyLogger:Log message number 9947
# DEBUG:MyLogger:Log message number 9948
# DEBUG:MyLogger:Log message number 9949
# DEBUG:MyLogger:Log message number 9950
# DEBUG:MyLogger:Log message number 9951
# DEBUG:MyLogger:Log message number 9952
# DEBUG:MyLogger:Log message number 9953
# DEBUG:MyLogger:Log message number 9954
# DEBUG:MyLogger:Log message number 9955
# DEBUG:MyLogger:Log message number 9956
# DEBUG:MyLogger:Log message number 9957
# DEBUG:MyLogger:Log message number 9958
# DEBUG:MyLogger:Log message number 9959
# DEBUG:MyLogger:Log message number 9960
# DEBUG:MyLogger:Log message number 9961
# DEBUG:MyLogger:Log message number 9962
# DEBUG:MyLogger:Log message number 9963
# DEBUG:MyLogger:Log message number 9964
# DEBUG:MyLogger:Log message number 9965
# DEBUG:MyLogger:Log message number 9966
# DEBUG:MyLogger:Log message number 9967
# DEBUG:MyLogger:Log message number 9968
# DEBUG:MyLogger:Log message number 9969
# DEBUG:MyLogger:Log message number 9970
# DEBUG:MyLogger:Log message number 9971
# DEBUG:MyLogger:Log message number 9972
# DEBUG:MyLogger:Log message number 9973
# DEBUG:MyLogger:Log message number 9974
# DEBUG:MyLogger:Log message number 9975
# DEBUG:MyLogger:Log message number 9976
# DEBUG:MyLogger:Log message number 9977
# DEBUG:MyLogger:Log message number 9978
# DEBUG:MyLogger:Log message number 9979
# DEBUG:MyLogger:Log message number 9980
# DEBUG:MyLogger:Log message number 9981
# DEBUG:MyLogger:Log message number 9982
# DEBUG:MyLogger:Log message number 9983
# DEBUG:MyLogger:Log message number 9984
# DEBUG:MyLogger:Log message number 9985
# DEBUG:MyLogger:Log message number 9986
# DEBUG:MyLogger:Log message number 9987
# DEBUG:MyLogger:Log message number 9988
# DEBUG:MyLogger:Log message number 9989
# DEBUG:MyLogger:Log message number 9990
# DEBUG:MyLogger:Log message number 9991
# DEBUG:MyLogger:Log message number 9992
# DEBUG:MyLogger:Log message number 9993
# DEBUG:MyLogger:Log message number 9994
# DEBUG:MyLogger:Log message number 9995
# DEBUG:MyLogger:Log message number 9996
# DEBUG:MyLogger:Log message number 9997
# DEBUG:MyLogger:Log message number 9998
# DEBUG:MyLogger:Log message number 9999

# %%
#19:- Write a program that handles both IndexError and KeyError using a try-except block
my_list = [1, 2, 3]
my_dict = {'a': 100, 'b': 200}

try:
    # Access an invalid list index
    print(my_list[5])

    # Access a missing dictionary key
    print(my_dict['c'])

except IndexError:
    print("Caught an IndexError: List index is out of range.")
except KeyError:
    print("Caught a KeyError: Dictionary key not found.")
# Out:
# Caught an IndexError: List index is out of range.

# %%
#20:- How would you open a file and read its contents using a context manager in Python
with open('sample.txt', 'r') as file:
    contents = file.read()
    print(contents)
# Out:
# Hello, Python!

# %%
#21:- Write a Python program that reads a file and prints the number of occurrences of a specific word
filename = 'sample.txt'
word_to_count = 'Python'

try:
    with open(filename, 'r') as file:
        content = file.read()
        # Count occurrences (case-insensitive)
        count = content.lower().split().count(word_to_count.lower())
    print(f"The word '{word_to_count}' occurs {count} times in the file.")
except FileNotFoundError:
    print(f"The file '{filename}' does not exist.")
# Out:
# The word 'Python' occurs 0 times in the file.

# %%
#22:- How can you check if a file is empty before attempting to read its contents
import os

filename = 'test.txt'

if os.path.exists(filename) and os.path.getsize(filename) > 0:
    with open(filename, 'r') as file:
        print(file.read())
else:
    print(f"The file '{filename}' is empty or does not exist.")
# Out:
# The file 'test.txt' is empty or does not exist.

# %%
#23:- Write a Python program that writes to a log file when an error occurs during file handling.
import logging

# Configure logging to write errors to a file
logging.basicConfig(
    filename='file_errors.log',
    level=logging.ERROR,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

filename = 'nonexistent_file.txt'

try:
    with open(filename, 'r') as file:
        content = file.read()
        print(content)
except (FileNotFoundError, IOError) as e:
    logging.error(f"Error while handling file '{filename}': {e}")
    print(f"An error occurred. Check 'file_errors.log' for details.")
# Out:
# ERROR:root:Error while handling file 'nonexistent_file.txt': [Errno 2] No such file or directory: 'nonexistent_file.txt'
# An error occurred. Check 'file_errors.log' for details.
